# %% [markdown]
# # Language Translation
# In this project, you’re going to take a peek into the realm of neural network machine translation.  You’ll be training a sequence to sequence model on a dataset of English and French sentences that can translate new sentences from English to French.
# ## Get the Data
# Since translating the whole language of English to French will take lots of time to train, we have provided you with a small portion of the English corpus.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper
import problem_unittests as tests

source_path = 'data/small_vocab_en'
target_path = 'data/small_vocab_fr'
source_text = helper.load_data(source_path)
target_text = helper.load_data(target_path)

# %% [markdown]
# ## Explore the Data
# Play around with view_sentence_range to view different parts of the data.

# %%
view_sentence_range = (0, 10)

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

print('Dataset Stats')
print('Roughly the number of unique words: {}'.format(len({word: None for word in source_text.split()})))

sentences = source_text.split('\n')
word_counts = [len(sentence.split()) for sentence in sentences]
print('Number of sentences: {}'.format(len(sentences)))
print('Average number of words in a sentence: {}'.format(np.average(word_counts)))

print()
print('English sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(source_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
print()
print('French sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(target_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
# Out:
# Dataset Stats
# Roughly the number of unique words: 227
# Number of sentences: 137861
# Average number of words in a sentence: 13.225277634719028
#
# English sentences 0 to 10:
# new jersey is sometimes quiet during autumn , and it is snowy in april .
# the united states is usually chilly during july , and it is usually freezing in november .
# california is usually quiet during march , and it is usually hot in june .
# the united states is sometimes mild during june , and it is cold in september .
# your least liked fruit is the grape , but my least liked is the apple .
# his favorite fruit is the orange , but my favorite is the grape .
# paris is relaxing during december , but it is usually chilly in july .
# new jersey is busy during spring , and it is never hot in march .
# our least liked fruit is the lemon , but my least liked is the grape .
# the united states is sometimes busy during january , and it is sometimes warm in november .
#
# French sentences 0 to 10:
# new jersey est parfois calme pendant l' automne , et il est neigeux en avril .
# les états-unis est généralement froid en juillet , et il gèle habituellement en novembre .
# california est généralement calme en mars , et il est généralement chaud en juin .
# les états-unis est parfois légère en juin , et il fait froid en septembre .
# votre moins aimé fruit est le raisin , mais mon moins aimé est la pomme .
# son fruit préféré est l'orange , mais mon préféré est le raisin .
# paris est relaxant en décembre , mais il est généralement froid en juillet .
# new jersey est occupé au printemps , et il est jamais chaude en mars .
# notre fruit est moins aimé le citron , mais mon moins aimé est le raisin .
# les états-unis est parfois occupé en janvier , et il est parfois chaud en novembre .

# %% [markdown]
# ## Implement Preprocessing Function
# ### Text to Word Ids
# As you did with other RNNs, you must turn the text into a number so the computer can understand it. In the function `text_to_ids()`, you'll turn `source_text` and `target_text` from words to ids.  However, you need to add the `<EOS>` word id at the end of each sentence from `target_text`.  This will help the neural network predict when the sentence should end.
#
# You can get the `<EOS>` word id by doing:
# ```python
# target_vocab_to_int['<EOS>']
# ```
# You can get other word ids using `source_vocab_to_int` and `target_vocab_to_int`.

# %%
def text_to_ids(source_text, target_text, source_vocab_to_int, target_vocab_to_int):
    
    source_id_text = [[source_vocab_to_int.get(word, source_vocab_to_int['<UNK>']) for word in sentence.split()] for sentence in source_text.split('\n')]
    target_id_text = [[target_vocab_to_int.get(word, target_vocab_to_int['<UNK>']) for word in sentence.split()] for sentence in target_text.split('\n')]  
    for i in range(len(target_id_text)):
        target_id_text[i].append(target_vocab_to_int['<EOS>'])
    return (source_id_text, target_id_text)

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_text_to_ids(text_to_ids)
# Out:
# Tests Passed

# %% [markdown]
# ### Preprocess all the data and save it
# Running the code cell below will preprocess all the data and save it to file.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
helper.preprocess_and_save_data(source_path, target_path, text_to_ids)

# %% [markdown]
# # Check Point
# This is your first checkpoint. If you ever decide to come back to this notebook or have to restart the notebook, you can start from here. The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np
import helper

(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()

# %% [markdown]
# ### Check the Version of TensorFlow and Access to GPU
# This will check to make sure you have the correct version of TensorFlow and access to a GPU

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf

# Check TensorFlow Version
assert LooseVersion(tf.__version__) >= LooseVersion('1.0'), 'Please use TensorFlow version 1.0 or newer'
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.0.0
# Default GPU Device: /gpu:0

# %% [markdown]
# ## Build the Neural Network
# You'll build the components necessary to build a Sequence-to-Sequence model by implementing the following functions below:
# - `model_inputs`
# - `process_decoding_input`
# - `encoding_layer`
# - `decoding_layer_train`
# - `decoding_layer_infer`
# - `decoding_layer`
# - `seq2seq_model`
#
# ### Input
# Implement the `model_inputs()` function to create TF Placeholders for the Neural Network. It should create the following placeholders:
#
# - Input text placeholder named "input" using the TF Placeholder name parameter with rank 2.
# - Targets placeholder with rank 2.
# - Learning rate placeholder with rank 0.
# - Keep probability placeholder named "keep_prob" using the TF Placeholder name parameter with rank 0.
#
# Return the placeholders in the following the tuple (Input, Targets, Learing Rate, Keep Probability)

# %%
def model_inputs():
    """
    Create TF Placeholders for input, targets, and learning rate.
    :return: Tuple (input, targets, learning rate, keep probability)
    """
    # TODO: Implement Function
    inputs = tf.placeholder(tf.int32, [None, None], name="input")
    targets = tf.placeholder(tf.int32, [None, None])
    learning_rate = tf.placeholder(tf.float32)
    keep_probs = tf.placeholder(tf.float32, name="keep_prob")
    return (inputs, targets, learning_rate, keep_probs)

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### Process Decoding Input
# Implement `process_decoding_input` using TensorFlow to remove the last word id from each batch in `target_data` and concat the GO ID to the begining of each batch.

# %%
def process_decoding_input(target_data, target_vocab_to_int, batch_size):
    
    ending = tf.strided_slice(target_data, [0, 0], [batch_size, -1], [1, 1])
    dec_input = tf.concat([tf.fill([batch_size, 1], target_vocab_to_int['<GO>']), ending], 1)
    return dec_input

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_process_decoding_input(process_decoding_input)
# Out:
# Tests Passed

# %% [markdown]
# ### Encoding
# Implement `encoding_layer()` to create a Encoder RNN layer using [`tf.nn.dynamic_rnn()`](https://www.tensorflow.org/api_docs/python/tf/nn/dynamic_rnn).

# %%
def encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob):
    
    cell = tf.contrib.rnn.MultiRNNCell([tf.contrib.rnn.BasicLSTMCell(rnn_size)] * num_layers)
    drop_cell = tf.contrib.rnn.DropoutWrapper(cell, output_keep_prob=keep_prob)
    _, rnn_state = tf.nn.dynamic_rnn(drop_cell, rnn_inputs, dtype=tf.float32)
    return rnn_state

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_encoding_layer(encoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Training
# Create training logits using [`tf.contrib.seq2seq.simple_decoder_fn_train()`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/simple_decoder_fn_train) and [`tf.contrib.seq2seq.dynamic_rnn_decoder()`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_rnn_decoder).  Apply the `output_fn` to the [`tf.contrib.seq2seq.dynamic_rnn_decoder()`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_rnn_decoder) outputs.

# %%
def decoding_layer_train(encoder_state, dec_cell, dec_embed_input, sequence_length, decoding_scope,
                         output_fn, keep_prob):
    
    train_decoder_fn = tf.contrib.seq2seq.simple_decoder_fn_train(encoder_state)
    drop_cell = tf.contrib.rnn.DropoutWrapper(dec_cell, output_keep_prob=keep_prob)
    train_pred, _, _ = tf.contrib.seq2seq.dynamic_rnn_decoder(
        drop_cell, train_decoder_fn, dec_embed_input, sequence_length, scope=decoding_scope)
    train_logits = output_fn(train_pred)
    return train_logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_train(decoding_layer_train)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Inference
# Create inference logits using [`tf.contrib.seq2seq.simple_decoder_fn_inference()`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/simple_decoder_fn_inference) and [`tf.contrib.seq2seq.dynamic_rnn_decoder()`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_rnn_decoder).

# %%
def decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id,
                         maximum_length, vocab_size, decoding_scope, output_fn, keep_prob):
    
    infer_decoder_fn = tf.contrib.seq2seq.simple_decoder_fn_inference(
        output_fn, encoder_state, dec_embeddings, start_of_sequence_id, end_of_sequence_id, 
        maximum_length - 1, vocab_size)
    drop_cell = tf.contrib.rnn.DropoutWrapper(dec_cell, output_keep_prob=keep_prob)
    inference_logits, _, _ = tf.contrib.seq2seq.dynamic_rnn_decoder(drop_cell, infer_decoder_fn, scope=decoding_scope)
    
    return inference_logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_infer(decoding_layer_infer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Decoding Layer
# Implement `decoding_layer()` to create a Decoder RNN layer.
#
# - Create RNN cell for decoding using `rnn_size` and `num_layers`.
# - Create the output fuction using [`lambda`](https://docs.python.org/3/tutorial/controlflow.html#lambda-expressions) to transform it's input, logits, to class logits.
# - Use the your `decoding_layer_train(encoder_state, dec_cell, dec_embed_input, sequence_length, decoding_scope, output_fn, keep_prob)` function to get the training logits.
# - Use your `decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id, maximum_length, vocab_size, decoding_scope, output_fn, keep_prob)` function to get the inference logits.
#
# Note: You'll need to use [tf.variable_scope](https://www.tensorflow.org/api_docs/python/tf/variable_scope) to share variables between training and inference.

# %%
def decoding_layer(dec_embed_input, dec_embeddings, encoder_state, vocab_size, sequence_length, rnn_size,
                   num_layers, target_vocab_to_int, keep_prob):

    rnn_cell = tf.contrib.rnn.MultiRNNCell([tf.contrib.rnn.BasicLSTMCell(rnn_size)] * num_layers)
    
    with tf.variable_scope("decoding") as decoding_scope:
        output_fn = lambda x: tf.contrib.layers.fully_connected(x, vocab_size, None, scope=decoding_scope)
    
    with tf.variable_scope("decoding") as decoding_scope:
        training_logits = decoding_layer_train(encoder_state, rnn_cell, dec_embed_input, sequence_length, decoding_scope,
                         output_fn, keep_prob)
    
    with tf.variable_scope("decoding", reuse=True) as decoding_scope:
        inference_logits = decoding_layer_infer(encoder_state, rnn_cell, dec_embeddings, target_vocab_to_int['<GO>'], target_vocab_to_int['<EOS>'],
                         sequence_length, vocab_size, decoding_scope, output_fn, keep_prob)

    
    return (training_logits, inference_logits)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer(decoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Neural Network
# Apply the functions you implemented above to:
#
# - Apply embedding to the input data for the encoder.
# - Encode the input using your `encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob)`.
# - Process target data using your `process_decoding_input(target_data, target_vocab_to_int, batch_size)` function.
# - Apply embedding to the target data for the decoder.
# - Decode the encoded input using your `decoding_layer(dec_embed_input, dec_embeddings, encoder_state, vocab_size, sequence_length, rnn_size, num_layers, target_vocab_to_int, keep_prob)`.

# %%
def seq2seq_model(input_data, target_data, keep_prob, batch_size, sequence_length, source_vocab_size, target_vocab_size,
                  enc_embedding_size, dec_embedding_size, rnn_size, num_layers, target_vocab_to_int):
    """
    Build the Sequence-to-Sequence part of the neural network
    :param input_data: Input placeholder
    :param target_data: Target placeholder
    :param keep_prob: Dropout keep probability placeholder
    :param batch_size: Batch Size
    :param sequence_length: Sequence Length
    :param source_vocab_size: Source vocabulary size
    :param target_vocab_size: Target vocabulary size
    :param enc_embedding_size: Decoder embedding size
    :param dec_embedding_size: Encoder embedding size
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: Tuple of (Training Logits, Inference Logits)
    """
    # TODO: Implement Function
    enc_embed_input = tf.contrib.layers.embed_sequence(input_data, source_vocab_size, enc_embedding_size)
    enc_state = encoding_layer(enc_embed_input, rnn_size, num_layers, keep_prob)
    dec_input = process_decoding_input(target_data, target_vocab_to_int, batch_size)
    #dec_embed_input = tf.contrib.layers.embed_sequence(target_data, target_vocab_size, dec_embedding_size)
    dec_embeddings = tf.Variable(tf.random_uniform([target_vocab_size, dec_embedding_size]))
    dec_embed_input = tf.nn.embedding_lookup(dec_embeddings, dec_input)

    training_logits, inference_logits = decoding_layer(dec_embed_input, dec_embeddings, enc_state, target_vocab_size, sequence_length, rnn_size,
                   num_layers, target_vocab_to_int, keep_prob)
    return (training_logits, inference_logits)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_seq2seq_model(seq2seq_model)
# Out:
# Tests Passed

# %% [markdown]
# ## Neural Network Training
# ### Hyperparameters
# Tune the following parameters:
#
# - Set `epochs` to the number of epochs.
# - Set `batch_size` to the batch size.
# - Set `rnn_size` to the size of the RNNs.
# - Set `num_layers` to the number of layers.
# - Set `encoding_embedding_size` to the size of the embedding for the encoder.
# - Set `decoding_embedding_size` to the size of the embedding for the decoder.
# - Set `learning_rate` to the learning rate.
# - Set `keep_probability` to the Dropout keep probability

# %%
# Number of Epochs
epochs = 20
# Batch Size
batch_size = 512
# RNN Size
rnn_size = 128
# Number of Layers
num_layers = 2
# Embedding Size
encoding_embedding_size = 13
decoding_embedding_size = 13
# Learning Rate
learning_rate = 0.001
# Dropout Keep Probability
keep_probability = 0.5

# %% [markdown]
# ### Build the Graph
# Build the graph using the neural network you implemented.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_path = 'checkpoints/dev'
(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()
max_target_sentence_length = max([len(sentence) for sentence in source_int_text])

train_graph = tf.Graph()
with train_graph.as_default():
    input_data, targets, lr, keep_prob = model_inputs()
    sequence_length = tf.placeholder_with_default(max_target_sentence_length, None, name='sequence_length')
    input_shape = tf.shape(input_data)
    
    train_logits, inference_logits = seq2seq_model(
        tf.reverse(input_data, [-1]), targets, keep_prob, batch_size, sequence_length, len(source_vocab_to_int), len(target_vocab_to_int),
        encoding_embedding_size, decoding_embedding_size, rnn_size, num_layers, target_vocab_to_int)

    tf.identity(inference_logits, 'logits')
    with tf.name_scope("optimization"):
        # Loss function
        cost = tf.contrib.seq2seq.sequence_loss(
            train_logits,
            targets,
            tf.ones([input_shape[0], sequence_length]))

        # Optimizer
        optimizer = tf.train.AdamOptimizer(lr)

        # Gradient Clipping
        gradients = optimizer.compute_gradients(cost)
        capped_gradients = [(tf.clip_by_value(grad, -1., 1.), var) for grad, var in gradients if grad is not None]
        train_op = optimizer.apply_gradients(capped_gradients)

# %% [markdown]
# ### Train
# Train the neural network on the preprocessed data. If you have a hard time getting a good loss, check the forms to see if anyone is having the same problem.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import time

def get_accuracy(target, logits):
    """
    Calculate accuracy
    """
    max_seq = max(target.shape[1], logits.shape[1])
    if max_seq - target.shape[1]:
        target = np.pad(
            target_batch,
            [(0,0),(0,max_seq - target_batch.shape[1]), (0,0)],
            'constant')
    if max_seq - batch_train_logits.shape[1]:
        logits = np.pad(
            logits,
            [(0,0),(0,max_seq - logits.shape[1]), (0,0)],
            'constant')

    return np.mean(np.equal(target, np.argmax(logits, 2)))

train_source = source_int_text[batch_size:]
train_target = target_int_text[batch_size:]

valid_source = helper.pad_sentence_batch(source_int_text[:batch_size])
valid_target = helper.pad_sentence_batch(target_int_text[:batch_size])

with tf.Session(graph=train_graph) as sess:
    sess.run(tf.global_variables_initializer())

    for epoch_i in range(epochs):
        for batch_i, (source_batch, target_batch) in enumerate(
                helper.batch_data(train_source, train_target, batch_size)):
            start_time = time.time()
            
            _, loss = sess.run(
                [train_op, cost],
                {input_data: source_batch,
                 targets: target_batch,
                 lr: learning_rate,
                 sequence_length: target_batch.shape[1],
                 keep_prob: keep_probability})
            
            batch_train_logits = sess.run(
                inference_logits,
                {input_data: source_batch, keep_prob: 1.0})
            batch_valid_logits = sess.run(
                inference_logits,
                {input_data: valid_source, keep_prob: 1.0})
                
            train_acc = get_accuracy(target_batch, batch_train_logits)
            valid_acc = get_accuracy(np.array(valid_target), batch_valid_logits)
            end_time = time.time()
            print('Epoch {:>3} Batch {:>4}/{} - Train Accuracy: {:>6.3f}, Validation Accuracy: {:>6.3f}, Loss: {:>6.3f}'
                  .format(epoch_i, batch_i, len(source_int_text) // batch_size, train_acc, valid_acc, loss))

    # Save Model
    saver = tf.train.Saver()
    saver.save(sess, save_path)
    print('Model Trained and Saved')
# Out:
# Epoch   0 Batch    0/269 - Train Accuracy:  0.184, Validation Accuracy:  0.262, Loss:  5.886
# Epoch   0 Batch    1/269 - Train Accuracy:  0.233, Validation Accuracy:  0.310, Loss:  5.836
# Epoch   0 Batch    2/269 - Train Accuracy:  0.266, Validation Accuracy:  0.310, Loss:  5.770
# Epoch   0 Batch    3/269 - Train Accuracy:  0.244, Validation Accuracy:  0.310, Loss:  5.709
# Epoch   0 Batch    4/269 - Train Accuracy:  0.232, Validation Accuracy:  0.310, Loss:  5.623
# Epoch   0 Batch    5/269 - Train Accuracy:  0.237, Validation Accuracy:  0.314, Loss:  5.491
# Epoch   0 Batch    6/269 - Train Accuracy:  0.288, Validation Accuracy:  0.320, Loss:  5.232
# Epoch   0 Batch    7/269 - Train Accuracy:  0.288, Validation Accuracy:  0.322, Loss:  5.028
# Epoch   0 Batch    8/269 - Train Accuracy:  0.253, Validation Accuracy:  0.322, Loss:  4.936
# Epoch   0 Batch    9/269 - Train Accuracy:  0.280, Validation Accuracy:  0.322, Loss:  4.671
# Epoch   0 Batch   10/269 - Train Accuracy:  0.246, Validation Accuracy:  0.322, Loss:  4.642
# Epoch   0 Batch   11/269 - Train Accuracy:  0.284, Validation Accuracy:  0.322, Loss:  4.361
# Epoch   0 Batch   12/269 - Train Accuracy:  0.270, Validation Accuracy:  0.335, Loss:  4.360
# Epoch   0 Batch   13/269 - Train Accuracy:  0.341, Validation Accuracy:  0.340, Loss:  3.986
# Epoch   0 Batch   14/269 - Train Accuracy:  0.303, Validation Accuracy:  0.341, Loss:  4.076
# Epoch   0 Batch   15/269 - Train Accuracy:  0.294, Validation Accuracy:  0.341, Loss:  4.034
# Epoch   0 Batch   16/269 - Train Accuracy:  0.311, Validation Accuracy:  0.342, Loss:  3.905
# Epoch   0 Batch   17/269 - Train Accuracy:  0.302, Validation Accuracy:  0.343, Loss:  3.853
# Epoch   0 Batch   18/269 - Train Accuracy:  0.271, Validation Accuracy:  0.343, Loss:  3.917
# Epoch   0 Batch   19/269 - Train Accuracy:  0.341, Validation Accuracy:  0.343, Loss:  3.533
# Epoch   0 Batch   20/269 - Train Accuracy:  0.275, Validation Accuracy:  0.343, Loss:  3.758
# Epoch   0 Batch   21/269 - Train Accuracy:  0.277, Validation Accuracy:  0.343, Loss:  3.715
# Epoch   0 Batch   22/269 - Train Accuracy:  0.315, Validation Accuracy:  0.343, Loss:  3.508
# Epoch   0 Batch   23/269 - Train Accuracy:  0.326, Validation Accuracy:  0.343, Loss:  3.459
# Epoch   0 Batch   24/269 - Train Accuracy:  0.272, Validation Accuracy:  0.343, Loss:  3.608
# Epoch   0 Batch   25/269 - Train Accuracy:  0.278, Validation Accuracy:  0.343, Loss:  3.593
# Epoch   0 Batch   26/269 - Train Accuracy:  0.344, Validation Accuracy:  0.343, Loss:  3.264
# Epoch   0 Batch   27/269 - Train Accuracy:  0.321, Validation Accuracy:  0.355, Loss:  3.399
# Epoch   0 Batch   28/269 - Train Accuracy:  0.292, Validation Accuracy:  0.369, Loss:  3.551
# Epoch   0 Batch   29/269 - Train Accuracy:  0.303, Validation Accuracy:  0.369, Loss:  3.492
# Epoch   0 Batch   30/269 - Train Accuracy:  0.331, Validation Accuracy:  0.369, Loss:  3.336
# Epoch   0 Batch   31/269 - Train Accuracy:  0.343, Validation Accuracy:  0.370, Loss:  3.308
# Epoch   0 Batch   32/269 - Train Accuracy:  0.331, Validation Accuracy:  0.368, Loss:  3.331
# Epoch   0 Batch   33/269 - Train Accuracy:  0.341, Validation Accuracy:  0.369, Loss:  3.243
# Epoch   0 Batch   34/269 - Train Accuracy:  0.339, Validation Accuracy:  0.371, Loss:  3.257
# Epoch   0 Batch   35/269 - Train Accuracy:  0.342, Validation Accuracy:  0.371, Loss:  3.238
# Epoch   0 Batch   36/269 - Train Accuracy:  0.339, Validation Accuracy:  0.371, Loss:  3.237
# Epoch   0 Batch   37/269 - Train Accuracy:  0.346, Validation Accuracy:  0.374, Loss:  3.224
# Epoch   0 Batch   38/269 - Train Accuracy:  0.339, Validation Accuracy:  0.371, Loss:  3.223
# Epoch   0 Batch   39/269 - Train Accuracy:  0.337, Validation Accuracy:  0.371, Loss:  3.199
# Epoch   0 Batch   40/269 - Train Accuracy:  0.306, Validation Accuracy:  0.371, Loss:  3.328
# Epoch   0 Batch   41/269 - Train Accuracy:  0.336, Validation Accuracy:  0.371, Loss:  3.189
# Epoch   0 Batch   42/269 - Train Accuracy:  0.368, Validation Accuracy:  0.371, Loss:  3.046
# Epoch   0 Batch   43/269 - Train Accuracy:  0.315, Validation Accuracy:  0.371, Loss:  3.277
# Epoch   0 Batch   44/269 - Train Accuracy:  0.348, Validation Accuracy:  0.375, Loss:  3.140
# Epoch   0 Batch   45/269 - Train Accuracy:  0.315, Validation Accuracy:  0.376, Loss:  3.257
# Epoch   0 Batch   46/269 - Train Accuracy:  0.312, Validation Accuracy:  0.382, Loss:  3.256
# Epoch   0 Batch   47/269 - Train Accuracy:  0.380, Validation Accuracy:  0.382, Loss:  2.927
# Epoch   0 Batch   48/269 - Train Accuracy:  0.352, Validation Accuracy:  0.382, Loss:  3.041
# Epoch   0 Batch   49/269 - Train Accuracy:  0.323, Validation Accuracy:  0.382, Loss:  3.187
# Epoch   0 Batch   50/269 - Train Accuracy:  0.326, Validation Accuracy:  0.383, Loss:  3.165
# Epoch   0 Batch   51/269 - Train Accuracy:  0.346, Validation Accuracy:  0.381, Loss:  3.066
# Epoch   0 Batch   52/269 - Train Accuracy:  0.348, Validation Accuracy:  0.380, Loss:  3.007
# Epoch   0 Batch   53/269 - Train Accuracy:  0.325, Validation Accuracy:  0.385, Loss:  3.154
# Epoch   0 Batch   54/269 - Train Accuracy:  0.327, Validation Accuracy:  0.387, Loss:  3.135
# Epoch   0 Batch   55/269 - Train Accuracy:  0.356, Validation Accuracy:  0.388, Loss:  2.996
# Epoch   0 Batch   56/269 - Train Accuracy:  0.369, Validation Accuracy:  0.395, Loss:  2.977
# Epoch   0 Batch   57/269 - Train Accuracy:  0.372, Validation Accuracy:  0.399, Loss:  2.968
# Epoch   0 Batch   58/269 - Train Accuracy:  0.373, Validation Accuracy:  0.401, Loss:  2.957
# Epoch   0 Batch   59/269 - Train Accuracy:  0.373, Validation Accuracy:  0.404, Loss:  2.941
# Epoch   0 Batch   60/269 - Train Accuracy:  0.395, Validation Accuracy:  0.408, Loss:  2.857
# Epoch   0 Batch   61/269 - Train Accuracy:  0.411, Validation Accuracy:  0.409, Loss:  2.799
# Epoch   0 Batch   62/269 - Train Accuracy:  0.410, Validation Accuracy:  0.414, Loss:  2.815
# Epoch   0 Batch   63/269 - Train Accuracy:  0.381, Validation Accuracy:  0.411, Loss:  2.908
# Epoch   0 Batch   64/269 - Train Accuracy:  0.376, Validation Accuracy:  0.410, Loss:  2.906
# Epoch   0 Batch   65/269 - Train Accuracy:  0.383, Validation Accuracy:  0.411, Loss:  2.884
# Epoch   0 Batch   66/269 - Train Accuracy:  0.412, Validation Accuracy:  0.420, Loss:  2.801
# Epoch   0 Batch   67/269 - Train Accuracy:  0.389, Validation Accuracy:  0.421, Loss:  2.909
# Epoch   0 Batch   68/269 - Train Accuracy:  0.393, Validation Accuracy:  0.421, Loss:  2.891
# Epoch   0 Batch   69/269 - Train Accuracy:  0.361, Validation Accuracy:  0.420, Loss:  3.035
# Epoch   0 Batch   70/269 - Train Accuracy:  0.400, Validation Accuracy:  0.425, Loss:  2.842
# Epoch   0 Batch   71/269 - Train Accuracy:  0.370, Validation Accuracy:  0.426, Loss:  2.987
# Epoch   0 Batch   72/269 - Train Accuracy:  0.424, Validation Accuracy:  0.429, Loss:  2.752
# Epoch   0 Batch   73/269 - Train Accuracy:  0.403, Validation Accuracy:  0.429, Loss:  2.846
# Epoch   0 Batch   74/269 - Train Accuracy:  0.377, Validation Accuracy:  0.428, Loss:  2.954
# Epoch   0 Batch   75/269 - Train Accuracy:  0.404, Validation Accuracy:  0.430, Loss:  2.830
# Epoch   0 Batch   76/269 - Train Accuracy:  0.389, Validation Accuracy:  0.430, Loss:  2.860
# Epoch   0 Batch   77/269 - Train Accuracy:  0.407, Validation Accuracy:  0.431, Loss:  2.800
# Epoch   0 Batch   78/269 - Train Accuracy:  0.406, Validation Accuracy:  0.433, Loss:  2.823
# Epoch   0 Batch   79/269 - Train Accuracy:  0.402, Validation Accuracy:  0.432, Loss:  2.809
# Epoch   0 Batch   80/269 - Train Accuracy:  0.418, Validation Accuracy:  0.434, Loss:  2.747
# Epoch   0 Batch   81/269 - Train Accuracy:  0.415, Validation Accuracy:  0.439, Loss:  2.795
# Epoch   0 Batch   82/269 - Train Accuracy:  0.421, Validation Accuracy:  0.440, Loss:  2.754
# Epoch   0 Batch   83/269 - Train Accuracy:  0.427, Validation Accuracy:  0.442, Loss:  2.738
# Epoch   0 Batch   84/269 - Train Accuracy:  0.420, Validation Accuracy:  0.443, Loss:  2.748
# Epoch   0 Batch   85/269 - Train Accuracy:  0.408, Validation Accuracy:  0.441, Loss:  2.775
# Epoch   0 Batch   86/269 - Train Accuracy:  0.416, Validation Accuracy:  0.442, Loss:  2.771
# Epoch   0 Batch   87/269 - Train Accuracy:  0.380, Validation Accuracy:  0.440, Loss:  2.916
# Epoch   0 Batch   88/269 - Train Accuracy:  0.423, Validation Accuracy:  0.443, Loss:  2.737
# Epoch   0 Batch   89/269 - Train Accuracy:  0.423, Validation Accuracy:  0.443, Loss:  2.705
# Epoch   0 Batch   90/269 - Train Accuracy:  0.360, Validation Accuracy:  0.415, Loss:  2.875
# Epoch   0 Batch   91/269 - Train Accuracy:  0.412, Validation Accuracy:  0.440, Loss:  2.731
# Epoch   0 Batch   92/269 - Train Accuracy:  0.416, Validation Accuracy:  0.442, Loss:  2.709
# Epoch   0 Batch   93/269 - Train Accuracy:  0.426, Validation Accuracy:  0.423, Loss:  2.612
# Epoch   0 Batch   94/269 - Train Accuracy:  0.429, Validation Accuracy:  0.449, Loss:  2.707
# Epoch   0 Batch   95/269 - Train Accuracy:  0.418, Validation Accuracy:  0.444, Loss:  2.687
# Epoch   0 Batch   96/269 - Train Accuracy:  0.422, Validation Accuracy:  0.454, Loss:  2.702
# Epoch   0 Batch   97/269 - Train Accuracy:  0.412, Validation Accuracy:  0.431, Loss:  2.668
# Epoch   0 Batch   98/269 - Train Accuracy:  0.439, Validation Accuracy:  0.456, Loss:  2.647
# Epoch   0 Batch   99/269 - Train Accuracy:  0.397, Validation Accuracy:  0.453, Loss:  2.794
# Epoch   0 Batch  100/269 - Train Accuracy:  0.453, Validation Accuracy:  0.459, Loss:  2.599
# Epoch   0 Batch  101/269 - Train Accuracy:  0.394, Validation Accuracy:  0.449, Loss:  2.781
# Epoch   0 Batch  102/269 - Train Accuracy:  0.421, Validation Accuracy:  0.453, Loss:  2.647
# Epoch   0 Batch  103/269 - Train Accuracy:  0.430, Validation Accuracy:  0.454, Loss:  2.632
# Epoch   0 Batch  104/269 - Train Accuracy:  0.429, Validation Accuracy:  0.460, Loss:  2.646
# Epoch   0 Batch  105/269 - Train Accuracy:  0.425, Validation Accuracy:  0.460, Loss:  2.619
# Epoch   0 Batch  106/269 - Train Accuracy:  0.422, Validation Accuracy:  0.450, Loss:  2.631
# Epoch   0 Batch  107/269 - Train Accuracy:  0.396, Validation Accuracy:  0.464, Loss:  2.763
# Epoch   0 Batch  108/269 - Train Accuracy:  0.428, Validation Accuracy:  0.463, Loss:  2.614
# Epoch   0 Batch  109/269 - Train Accuracy:  0.428, Validation Accuracy:  0.459, Loss:  2.616
# Epoch   0 Batch  110/269 - Train Accuracy:  0.434, Validation Accuracy:  0.456, Loss:  2.582
# Epoch   0 Batch  111/269 - Train Accuracy:  0.410, Validation Accuracy:  0.464, Loss:  2.730
# Epoch   0 Batch  112/269 - Train Accuracy:  0.435, Validation Accuracy:  0.466, Loss:  2.560
# Epoch   0 Batch  113/269 - Train Accuracy:  0.454, Validation Accuracy:  0.451, Loss:  2.463
# Epoch   0 Batch  114/269 - Train Accuracy:  0.440, Validation Accuracy:  0.465, Loss:  2.556
# Epoch   0 Batch  115/269 - Train Accuracy:  0.412, Validation Accuracy:  0.466, Loss:  2.657
# Epoch   0 Batch  116/269 - Train Accuracy:  0.440, Validation Accuracy:  0.463, Loss:  2.541
# Epoch   0 Batch  117/269 - Train Accuracy:  0.432, Validation Accuracy:  0.465, Loss:  2.556
# Epoch   0 Batch  118/269 - Train Accuracy:  0.458, Validation Accuracy:  0.470, Loss:  2.470
# Epoch   0 Batch  119/269 - Train Accuracy:  0.410, Validation Accuracy:  0.452, Loss:  2.630
# Epoch   0 Batch  120/269 - Train Accuracy:  0.412, Validation Accuracy:  0.471, Loss:  2.641
# Epoch   0 Batch  121/269 - Train Accuracy:  0.438, Validation Accuracy:  0.469, Loss:  2.502
# Epoch   0 Batch  122/269 - Train Accuracy:  0.443, Validation Accuracy:  0.459, Loss:  2.474
# Epoch   0 Batch  123/269 - Train Accuracy:  0.417, Validation Accuracy:  0.471, Loss:  2.612
# Epoch   0 Batch  124/269 - Train Accuracy:  0.431, Validation Accuracy:  0.463, Loss:  2.489
# Epoch   0 Batch  125/269 - Train Accuracy:  0.435, Validation Accuracy:  0.458, Loss:  2.460
# Epoch   0 Batch  126/269 - Train Accuracy:  0.449, Validation Accuracy:  0.468, Loss:  2.440
# Epoch   0 Batch  127/269 - Train Accuracy:  0.386, Validation Accuracy:  0.437, Loss:  2.596
# Epoch   0 Batch  128/269 - Train Accuracy:  0.434, Validation Accuracy:  0.460, Loss:  2.489
# Epoch   0 Batch  129/269 - Train Accuracy:  0.442, Validation Accuracy:  0.470, Loss:  2.548
# Epoch   0 Batch  130/269 - Train Accuracy:  0.378, Validation Accuracy:  0.437, Loss:  2.598
# Epoch   0 Batch  131/269 - Train Accuracy:  0.428, Validation Accuracy:  0.479, Loss:  2.612
# Epoch   0 Batch  132/269 - Train Accuracy:  0.430, Validation Accuracy:  0.467, Loss:  2.468
# Epoch   0 Batch  133/269 - Train Accuracy:  0.441, Validation Accuracy:  0.462, Loss:  2.480
# Epoch   0 Batch  134/269 - Train Accuracy:  0.397, Validation Accuracy:  0.449, Loss:  2.542
# Epoch   0 Batch  135/269 - Train Accuracy:  0.410, Validation Accuracy:  0.476, Loss:  2.641
# Epoch   0 Batch  136/269 - Train Accuracy:  0.412, Validation Accuracy:  0.469, Loss:  2.545
# Epoch   0 Batch  137/269 - Train Accuracy:  0.429, Validation Accuracy:  0.476, Loss:  2.560
# Epoch   0 Batch  138/269 - Train Accuracy:  0.409, Validation Accuracy:  0.453, Loss:  2.487
# Epoch   0 Batch  139/269 - Train Accuracy:  0.442, Validation Accuracy:  0.464, Loss:  2.414
# Epoch   0 Batch  140/269 - Train Accuracy:  0.454, Validation Accuracy:  0.478, Loss:  2.402
# Epoch   0 Batch  141/269 - Train Accuracy:  0.436, Validation Accuracy:  0.475, Loss:  2.466
# Epoch   0 Batch  142/269 - Train Accuracy:  0.449, Validation Accuracy:  0.477, Loss:  2.393
# Epoch   0 Batch  143/269 - Train Accuracy:  0.440, Validation Accuracy:  0.463, Loss:  2.383
# Epoch   0 Batch  144/269 - Train Accuracy:  0.463, Validation Accuracy:  0.483, Loss:  2.384
# Epoch   0 Batch  145/269 - Train Accuracy:  0.443, Validation Accuracy:  0.480, Loss:  2.388
# Epoch   0 Batch  146/269 - Train Accuracy:  0.457, Validation Accuracy:  0.481, Loss:  2.368
# Epoch   0 Batch  147/269 - Train Accuracy:  0.475, Validation Accuracy:  0.471, Loss:  2.261
# Epoch   0 Batch  148/269 - Train Accuracy:  0.448, Validation Accuracy:  0.478, Loss:  2.406
# Epoch   0 Batch  149/269 - Train Accuracy:  0.454, Validation Accuracy:  0.481, Loss:  2.344
# Epoch   0 Batch  150/269 - Train Accuracy:  0.459, Validation Accuracy:  0.484, Loss:  2.355
# Epoch   0 Batch  151/269 - Train Accuracy:  0.479, Validation Accuracy:  0.472, Loss:  2.230
# Epoch   0 Batch  152/269 - Train Accuracy:  0.454, Validation Accuracy:  0.478, Loss:  2.353
# Epoch   0 Batch  153/269 - Train Accuracy:  0.453, Validation Accuracy:  0.477, Loss:  2.324
# Epoch   0 Batch  154/269 - Train Accuracy:  0.421, Validation Accuracy:  0.479, Loss:  2.489
# Epoch   0 Batch  155/269 - Train Accuracy:  0.479, Validation Accuracy:  0.475, Loss:  2.199
# Epoch   0 Batch  156/269 - Train Accuracy:  0.434, Validation Accuracy:  0.479, Loss:  2.381
# Epoch   0 Batch  157/269 - Train Accuracy:  0.452, Validation Accuracy:  0.481, Loss:  2.317
# Epoch   0 Batch  158/269 - Train Accuracy:  0.461, Validation Accuracy:  0.479, Loss:  2.285
# Epoch   0 Batch  159/269 - Train Accuracy:  0.455, Validation Accuracy:  0.480, Loss:  2.313
# Epoch   0 Batch  160/269 - Train Accuracy:  0.446, Validation Accuracy:  0.475, Loss:  2.303
# Epoch   0 Batch  161/269 - Train Accuracy:  0.453, Validation Accuracy:  0.483, Loss:  2.327
# Epoch   0 Batch  162/269 - Train Accuracy:  0.462, Validation Accuracy:  0.486, Loss:  2.276
# Epoch   0 Batch  163/269 - Train Accuracy:  0.459, Validation Accuracy:  0.480, Loss:  2.267
# Epoch   0 Batch  164/269 - Train Accuracy:  0.465, Validation Accuracy:  0.478, Loss:  2.270
# Epoch   0 Batch  165/269 - Train Accuracy:  0.427, Validation Accuracy:  0.483, Loss:  2.369
# Epoch   0 Batch  166/269 - Train Accuracy:  0.485, Validation Accuracy:  0.484, Loss:  2.145
# Epoch   0 Batch  167/269 - Train Accuracy:  0.469, Validation Accuracy:  0.488, Loss:  2.244
# Epoch   0 Batch  168/269 - Train Accuracy:  0.468, Validation Accuracy:  0.489, Loss:  2.272
# Epoch   0 Batch  169/269 - Train Accuracy:  0.455, Validation Accuracy:  0.487, Loss:  2.248
# Epoch   0 Batch  170/269 - Train Accuracy:  0.462, Validation Accuracy:  0.482, Loss:  2.236
# Epoch   0 Batch  171/269 - Train Accuracy:  0.437, Validation Accuracy:  0.486, Loss:  2.315
# Epoch   0 Batch  172/269 - Train Accuracy:  0.462, Validation Accuracy:  0.487, Loss:  2.233
# Epoch   0 Batch  173/269 - Train Accuracy:  0.465, Validation Accuracy:  0.487, Loss:  2.227
# Epoch   0 Batch  174/269 - Train Accuracy:  0.457, Validation Accuracy:  0.487, Loss:  2.233
# Epoch   0 Batch  175/269 - Train Accuracy:  0.459, Validation Accuracy:  0.486, Loss:  2.242
# Epoch   0 Batch  176/269 - Train Accuracy:  0.440, Validation Accuracy:  0.486, Loss:  2.317
# Epoch   0 Batch  177/269 - Train Accuracy:  0.476, Validation Accuracy:  0.488, Loss:  2.139
# Epoch   0 Batch  178/269 - Train Accuracy:  0.439, Validation Accuracy:  0.487, Loss:  2.285
# Epoch   0 Batch  179/269 - Train Accuracy:  0.469, Validation Accuracy:  0.488, Loss:  2.199
# Epoch   0 Batch  180/269 - Train Accuracy:  0.462, Validation Accuracy:  0.487, Loss:  2.180
# Epoch   0 Batch  181/269 - Train Accuracy:  0.462, Validation Accuracy:  0.489, Loss:  2.176
# Epoch   0 Batch  182/269 - Train Accuracy:  0.468, Validation Accuracy:  0.486, Loss:  2.199
# Epoch   0 Batch  183/269 - Train Accuracy:  0.529, Validation Accuracy:  0.487, Loss:  1.914
# Epoch   0 Batch  184/269 - Train Accuracy:  0.445, Validation Accuracy:  0.491, Loss:  2.273
# Epoch   0 Batch  185/269 - Train Accuracy:  0.471, Validation Accuracy:  0.486, Loss:  2.141
# Epoch   0 Batch  186/269 - Train Accuracy:  0.436, Validation Accuracy:  0.486, Loss:  2.286
# Epoch   0 Batch  187/269 - Train Accuracy:  0.460, Validation Accuracy:  0.482, Loss:  2.138
# Epoch   0 Batch  188/269 - Train Accuracy:  0.477, Validation Accuracy:  0.486, Loss:  2.123
# Epoch   0 Batch  189/269 - Train Accuracy:  0.480, Validation Accuracy:  0.491, Loss:  2.145
# Epoch   0 Batch  190/269 - Train Accuracy:  0.473, Validation Accuracy:  0.494, Loss:  2.129
# Epoch   0 Batch  191/269 - Train Accuracy:  0.468, Validation Accuracy:  0.493, Loss:  2.166
# Epoch   0 Batch  192/269 - Train Accuracy:  0.472, Validation Accuracy:  0.492, Loss:  2.160
# Epoch   0 Batch  193/269 - Train Accuracy:  0.465, Validation Accuracy:  0.490, Loss:  2.147
# Epoch   0 Batch  194/269 - Train Accuracy:  0.465, Validation Accuracy:  0.482, Loss:  2.158
# Epoch   0 Batch  195/269 - Train Accuracy:  0.449, Validation Accuracy:  0.486, Loss:  2.190
# Epoch   0 Batch  196/269 - Train Accuracy:  0.465, Validation Accuracy:  0.491, Loss:  2.122
# Epoch   0 Batch  197/269 - Train Accuracy:  0.424, Validation Accuracy:  0.485, Loss:  2.235
# Epoch   0 Batch  198/269 - Train Accuracy:  0.443, Validation Accuracy:  0.494, Loss:  2.299
# Epoch   0 Batch  199/269 - Train Accuracy:  0.464, Validation Accuracy:  0.494, Loss:  2.168
# Epoch   0 Batch  200/269 - Train Accuracy:  0.451, Validation Accuracy:  0.490, Loss:  2.200
# Epoch   0 Batch  201/269 - Train Accuracy:  0.476, Validation Accuracy:  0.498, Loss:  2.128
# Epoch   0 Batch  202/269 - Train Accuracy:  0.462, Validation Accuracy:  0.494, Loss:  2.143
# Epoch   0 Batch  203/269 - Train Accuracy:  0.454, Validation Accuracy:  0.496, Loss:  2.206
# Epoch   0 Batch  204/269 - Train Accuracy:  0.450, Validation Accuracy:  0.493, Loss:  2.194
# Epoch   0 Batch  205/269 - Train Accuracy:  0.466, Validation Accuracy:  0.492, Loss:  2.111
# Epoch   0 Batch  206/269 - Train Accuracy:  0.440, Validation Accuracy:  0.494, Loss:  2.244
# Epoch   0 Batch  207/269 - Train Accuracy:  0.491, Validation Accuracy:  0.496, Loss:  2.021
# Epoch   0 Batch  208/269 - Train Accuracy:  0.442, Validation Accuracy:  0.492, Loss:  2.229
# Epoch   0 Batch  209/269 - Train Accuracy:  0.445, Validation Accuracy:  0.495, Loss:  2.179
# Epoch   0 Batch  210/269 - Train Accuracy:  0.478, Validation Accuracy:  0.495, Loss:  2.074
# Epoch   0 Batch  211/269 - Train Accuracy:  0.476, Validation Accuracy:  0.498, Loss:  2.074
# Epoch   0 Batch  212/269 - Train Accuracy:  0.489, Validation Accuracy:  0.497, Loss:  2.016
# Epoch   0 Batch  213/269 - Train Accuracy:  0.481, Validation Accuracy:  0.498, Loss:  2.058
# Epoch   0 Batch  214/269 - Train Accuracy:  0.480, Validation Accuracy:  0.496, Loss:  2.064
# Epoch   0 Batch  215/269 - Train Accuracy:  0.503, Validation Accuracy:  0.498, Loss:  1.951
# Epoch   0 Batch  216/269 - Train Accuracy:  0.445, Validation Accuracy:  0.501, Loss:  2.202
# Epoch   0 Batch  217/269 - Train Accuracy:  0.433, Validation Accuracy:  0.491, Loss:  2.170
# Epoch   0 Batch  218/269 - Train Accuracy:  0.447, Validation Accuracy:  0.487, Loss:  2.176
# Epoch   0 Batch  219/269 - Train Accuracy:  0.430, Validation Accuracy:  0.480, Loss:  2.172
# Epoch   0 Batch  220/269 - Train Accuracy:  0.483, Validation Accuracy:  0.490, Loss:  2.046
# Epoch   0 Batch  221/269 - Train Accuracy:  0.484, Validation Accuracy:  0.497, Loss:  2.061
# Epoch   0 Batch  222/269 - Train Accuracy:  0.472, Validation Accuracy:  0.491, Loss:  2.003
# Epoch   0 Batch  223/269 - Train Accuracy:  0.472, Validation Accuracy:  0.495, Loss:  2.020
# Epoch   0 Batch  224/269 - Train Accuracy:  0.480, Validation Accuracy:  0.498, Loss:  2.056
# Epoch   0 Batch  225/269 - Train Accuracy:  0.442, Validation Accuracy:  0.493, Loss:  2.136
# Epoch   0 Batch  226/269 - Train Accuracy:  0.472, Validation Accuracy:  0.500, Loss:  2.038
# Epoch   0 Batch  227/269 - Train Accuracy:  0.548, Validation Accuracy:  0.502, Loss:  1.792
# Epoch   0 Batch  228/269 - Train Accuracy:  0.459, Validation Accuracy:  0.495, Loss:  2.074
# Epoch   0 Batch  229/269 - Train Accuracy:  0.486, Validation Accuracy:  0.498, Loss:  2.035
# Epoch   0 Batch  230/269 - Train Accuracy:  0.472, Validation Accuracy:  0.500, Loss:  2.057
# Epoch   0 Batch  231/269 - Train Accuracy:  0.443, Validation Accuracy:  0.495, Loss:  2.117
# Epoch   0 Batch  232/269 - Train Accuracy:  0.446, Validation Accuracy:  0.503, Loss:  2.150
# Epoch   0 Batch  233/269 - Train Accuracy:  0.483, Validation Accuracy:  0.504, Loss:  2.056
# Epoch   0 Batch  234/269 - Train Accuracy:  0.472, Validation Accuracy:  0.498, Loss:  2.035
# Epoch   0 Batch  235/269 - Train Accuracy:  0.478, Validation Accuracy:  0.496, Loss:  2.027
# Epoch   0 Batch  236/269 - Train Accuracy:  0.480, Validation Accuracy:  0.500, Loss:  2.019
# Epoch   0 Batch  237/269 - Train Accuracy:  0.473, Validation Accuracy:  0.497, Loss:  2.010
# Epoch   0 Batch  238/269 - Train Accuracy:  0.481, Validation Accuracy:  0.503, Loss:  2.037
# Epoch   0 Batch  239/269 - Train Accuracy:  0.487, Validation Accuracy:  0.502, Loss:  2.004
# Epoch   0 Batch  240/269 - Train Accuracy:  0.504, Validation Accuracy:  0.495, Loss:  1.877
# Epoch   0 Batch  241/269 - Train Accuracy:  0.482, Validation Accuracy:  0.499, Loss:  1.992
# Epoch   0 Batch  242/269 - Train Accuracy:  0.471, Validation Accuracy:  0.503, Loss:  2.000
# Epoch   0 Batch  243/269 - Train Accuracy:  0.484, Validation Accuracy:  0.498, Loss:  1.963
# Epoch   0 Batch  244/269 - Train Accuracy:  0.480, Validation Accuracy:  0.497, Loss:  2.000
# Epoch   0 Batch  245/269 - Train Accuracy:  0.445, Validation Accuracy:  0.495, Loss:  2.138
# Epoch   0 Batch  246/269 - Train Accuracy:  0.477, Validation Accuracy:  0.498, Loss:  2.001
# Epoch   0 Batch  247/269 - Train Accuracy:  0.468, Validation Accuracy:  0.501, Loss:  2.055
# Epoch   0 Batch  248/269 - Train Accuracy:  0.464, Validation Accuracy:  0.501, Loss:  1.991
# Epoch   0 Batch  249/269 - Train Accuracy:  0.504, Validation Accuracy:  0.502, Loss:  1.916
# Epoch   0 Batch  250/269 - Train Accuracy:  0.466, Validation Accuracy:  0.506, Loss:  2.051
# Epoch   0 Batch  251/269 - Train Accuracy:  0.482, Validation Accuracy:  0.503, Loss:  1.974
# Epoch   0 Batch  252/269 - Train Accuracy:  0.469, Validation Accuracy:  0.502, Loss:  2.025
# Epoch   0 Batch  253/269 - Train Accuracy:  0.479, Validation Accuracy:  0.501, Loss:  1.984
# Epoch   0 Batch  254/269 - Train Accuracy:  0.482, Validation Accuracy:  0.501, Loss:  1.944
# Epoch   0 Batch  255/269 - Train Accuracy:  0.505, Validation Accuracy:  0.501, Loss:  1.907
# Epoch   0 Batch  256/269 - Train Accuracy:  0.459, Validation Accuracy:  0.501, Loss:  2.013
# Epoch   0 Batch  257/269 - Train Accuracy:  0.464, Validation Accuracy:  0.499, Loss:  1.980
# Epoch   0 Batch  258/269 - Train Accuracy:  0.467, Validation Accuracy:  0.501, Loss:  1.989
# Epoch   0 Batch  259/269 - Train Accuracy:  0.482, Validation Accuracy:  0.504, Loss:  1.965
# Epoch   0 Batch  260/269 - Train Accuracy:  0.464, Validation Accuracy:  0.505, Loss:  2.038
# Epoch   0 Batch  261/269 - Train Accuracy:  0.441, Validation Accuracy:  0.504, Loss:  2.090
# Epoch   0 Batch  262/269 - Train Accuracy:  0.482, Validation Accuracy:  0.503, Loss:  1.976
# Epoch   0 Batch  263/269 - Train Accuracy:  0.465, Validation Accuracy:  0.504, Loss:  2.039
# Epoch   0 Batch  264/269 - Train Accuracy:  0.456, Validation Accuracy:  0.504, Loss:  2.052
# Epoch   0 Batch  265/269 - Train Accuracy:  0.457, Validation Accuracy:  0.504, Loss:  2.026
# Epoch   0 Batch  266/269 - Train Accuracy:  0.484, Validation Accuracy:  0.505, Loss:  1.935
# Epoch   0 Batch  267/269 - Train Accuracy:  0.472, Validation Accuracy:  0.501, Loss:  1.973
# Epoch   1 Batch    0/269 - Train Accuracy:  0.459, Validation Accuracy:  0.501, Loss:  2.034
# Epoch   1 Batch    1/269 - Train Accuracy:  0.448, Validation Accuracy:  0.502, Loss:  2.028
# Epoch   1 Batch    2/269 - Train Accuracy:  0.466, Validation Accuracy:  0.504, Loss:  1.968
# Epoch   1 Batch    3/269 - Train Accuracy:  0.458, Validation Accuracy:  0.506, Loss:  2.019
# Epoch   1 Batch    4/269 - Train Accuracy:  0.453, Validation Accuracy:  0.499, Loss:  2.011
# Epoch   1 Batch    5/269 - Train Accuracy:  0.444, Validation Accuracy:  0.498, Loss:  2.035
# Epoch   1 Batch    6/269 - Train Accuracy:  0.485, Validation Accuracy:  0.501, Loss:  1.870
# Epoch   1 Batch    7/269 - Train Accuracy:  0.488, Validation Accuracy:  0.508, Loss:  1.915
# Epoch   1 Batch    8/269 - Train Accuracy:  0.453, Validation Accuracy:  0.505, Loss:  1.991
# Epoch   1 Batch    9/269 - Train Accuracy:  0.468, Validation Accuracy:  0.501, Loss:  1.929
# Epoch   1 Batch   10/269 - Train Accuracy:  0.447, Validation Accuracy:  0.497, Loss:  1.983
# Epoch   1 Batch   11/269 - Train Accuracy:  0.472, Validation Accuracy:  0.499, Loss:  1.955
# Epoch   1 Batch   12/269 - Train Accuracy:  0.456, Validation Accuracy:  0.506, Loss:  2.006
# Epoch   1 Batch   13/269 - Train Accuracy:  0.519, Validation Accuracy:  0.507, Loss:  1.804
# Epoch   1 Batch   14/269 - Train Accuracy:  0.474, Validation Accuracy:  0.503, Loss:  1.910
# Epoch   1 Batch   15/269 - Train Accuracy:  0.465, Validation Accuracy:  0.502, Loss:  1.921
# Epoch   1 Batch   16/269 - Train Accuracy:  0.479, Validation Accuracy:  0.499, Loss:  1.920
# Epoch   1 Batch   17/269 - Train Accuracy:  0.473, Validation Accuracy:  0.502, Loss:  1.887
# Epoch   1 Batch   18/269 - Train Accuracy:  0.459, Validation Accuracy:  0.508, Loss:  1.971
# Epoch   1 Batch   19/269 - Train Accuracy:  0.514, Validation Accuracy:  0.508, Loss:  1.818
# Epoch   1 Batch   20/269 - Train Accuracy:  0.470, Validation Accuracy:  0.505, Loss:  1.960
# Epoch   1 Batch   21/269 - Train Accuracy:  0.457, Validation Accuracy:  0.505, Loss:  2.013
# Epoch   1 Batch   22/269 - Train Accuracy:  0.482, Validation Accuracy:  0.501, Loss:  1.880
# Epoch   1 Batch   23/269 - Train Accuracy:  0.493, Validation Accuracy:  0.506, Loss:  1.887
# Epoch   1 Batch   24/269 - Train Accuracy:  0.457, Validation Accuracy:  0.506, Loss:  1.958
# Epoch   1 Batch   25/269 - Train Accuracy:  0.449, Validation Accuracy:  0.502, Loss:  1.960
# Epoch   1 Batch   26/269 - Train Accuracy:  0.513, Validation Accuracy:  0.506, Loss:  1.769
# Epoch   1 Batch   27/269 - Train Accuracy:  0.481, Validation Accuracy:  0.502, Loss:  1.891
# Epoch   1 Batch   28/269 - Train Accuracy:  0.436, Validation Accuracy:  0.507, Loss:  2.010
# Epoch   1 Batch   29/269 - Train Accuracy:  0.457, Validation Accuracy:  0.504, Loss:  1.958
# Epoch   1 Batch   30/269 - Train Accuracy:  0.480, Validation Accuracy:  0.505, Loss:  1.871
# Epoch   1 Batch   31/269 - Train Accuracy:  0.486, Validation Accuracy:  0.506, Loss:  1.849
# Epoch   1 Batch   32/269 - Train Accuracy:  0.470, Validation Accuracy:  0.495, Loss:  1.869
# Epoch   1 Batch   33/269 - Train Accuracy:  0.478, Validation Accuracy:  0.501, Loss:  1.845
# Epoch   1 Batch   34/269 - Train Accuracy:  0.458, Validation Accuracy:  0.480, Loss:  1.904
# Epoch   1 Batch   35/269 - Train Accuracy:  0.476, Validation Accuracy:  0.496, Loss:  1.907
# Epoch   1 Batch   36/269 - Train Accuracy:  0.480, Validation Accuracy:  0.503, Loss:  1.928
# Epoch   1 Batch   37/269 - Train Accuracy:  0.479, Validation Accuracy:  0.499, Loss:  1.895
# Epoch   1 Batch   38/269 - Train Accuracy:  0.468, Validation Accuracy:  0.503, Loss:  1.866
# Epoch   1 Batch   39/269 - Train Accuracy:  0.480, Validation Accuracy:  0.507, Loss:  1.877
# Epoch   1 Batch   40/269 - Train Accuracy:  0.460, Validation Accuracy:  0.506, Loss:  1.912
# Epoch   1 Batch   41/269 - Train Accuracy:  0.474, Validation Accuracy:  0.506, Loss:  1.859
# Epoch   1 Batch   42/269 - Train Accuracy:  0.497, Validation Accuracy:  0.502, Loss:  1.782
# Epoch   1 Batch   43/269 - Train Accuracy:  0.460, Validation Accuracy:  0.506, Loss:  1.894
# Epoch   1 Batch   44/269 - Train Accuracy:  0.489, Validation Accuracy:  0.509, Loss:  1.825
# Epoch   1 Batch   45/269 - Train Accuracy:  0.464, Validation Accuracy:  0.509, Loss:  1.909
# Epoch   1 Batch   46/269 - Train Accuracy:  0.460, Validation Accuracy:  0.506, Loss:  1.936
# Epoch   1 Batch   47/269 - Train Accuracy:  0.512, Validation Accuracy:  0.509, Loss:  1.720
# Epoch   1 Batch   48/269 - Train Accuracy:  0.488, Validation Accuracy:  0.509, Loss:  1.779
# Epoch   1 Batch   49/269 - Train Accuracy:  0.467, Validation Accuracy:  0.506, Loss:  1.879
# Epoch   1 Batch   50/269 - Train Accuracy:  0.462, Validation Accuracy:  0.506, Loss:  1.902
# Epoch   1 Batch   51/269 - Train Accuracy:  0.479, Validation Accuracy:  0.507, Loss:  1.851
# Epoch   1 Batch   52/269 - Train Accuracy:  0.482, Validation Accuracy:  0.507, Loss:  1.796
# Epoch   1 Batch   53/269 - Train Accuracy:  0.464, Validation Accuracy:  0.506, Loss:  1.894
# Epoch   1 Batch   54/269 - Train Accuracy:  0.465, Validation Accuracy:  0.507, Loss:  1.904
# Epoch   1 Batch   55/269 - Train Accuracy:  0.483, Validation Accuracy:  0.503, Loss:  1.802
# Epoch   1 Batch   56/269 - Train Accuracy:  0.497, Validation Accuracy:  0.507, Loss:  1.801
# Epoch   1 Batch   57/269 - Train Accuracy:  0.484, Validation Accuracy:  0.507, Loss:  1.811
# Epoch   1 Batch   58/269 - Train Accuracy:  0.491, Validation Accuracy:  0.504, Loss:  1.801
# Epoch   1 Batch   59/269 - Train Accuracy:  0.495, Validation Accuracy:  0.511, Loss:  1.783
# Epoch   1 Batch   60/269 - Train Accuracy:  0.495, Validation Accuracy:  0.505, Loss:  1.753
# Epoch   1 Batch   61/269 - Train Accuracy:  0.509, Validation Accuracy:  0.501, Loss:  1.709
# Epoch   1 Batch   62/269 - Train Accuracy:  0.506, Validation Accuracy:  0.509, Loss:  1.738
# Epoch   1 Batch   63/269 - Train Accuracy:  0.489, Validation Accuracy:  0.514, Loss:  1.774
# Epoch   1 Batch   64/269 - Train Accuracy:  0.478, Validation Accuracy:  0.509, Loss:  1.791
# Epoch   1 Batch   65/269 - Train Accuracy:  0.483, Validation Accuracy:  0.506, Loss:  1.782
# Epoch   1 Batch   66/269 - Train Accuracy:  0.491, Validation Accuracy:  0.505, Loss:  1.737
# Epoch   1 Batch   67/269 - Train Accuracy:  0.478, Validation Accuracy:  0.503, Loss:  1.802
# Epoch   1 Batch   68/269 - Train Accuracy:  0.475, Validation Accuracy:  0.509, Loss:  1.791
# Epoch   1 Batch   69/269 - Train Accuracy:  0.460, Validation Accuracy:  0.511, Loss:  1.900
# Epoch   1 Batch   70/269 - Train Accuracy:  0.498, Validation Accuracy:  0.506, Loss:  1.769
# Epoch   1 Batch   71/269 - Train Accuracy:  0.462, Validation Accuracy:  0.508, Loss:  1.869
# Epoch   1 Batch   72/269 - Train Accuracy:  0.498, Validation Accuracy:  0.504, Loss:  1.706
# Epoch   1 Batch   73/269 - Train Accuracy:  0.491, Validation Accuracy:  0.514, Loss:  1.797
# Epoch   1 Batch   74/269 - Train Accuracy:  0.471, Validation Accuracy:  0.511, Loss:  1.806
# Epoch   1 Batch   75/269 - Train Accuracy:  0.472, Validation Accuracy:  0.498, Loss:  1.754
# Epoch   1 Batch   76/269 - Train Accuracy:  0.467, Validation Accuracy:  0.510, Loss:  1.805
# Epoch   1 Batch   77/269 - Train Accuracy:  0.499, Validation Accuracy:  0.507, Loss:  1.763
# Epoch   1 Batch   78/269 - Train Accuracy:  0.477, Validation Accuracy:  0.507, Loss:  1.782
# Epoch   1 Batch   79/269 - Train Accuracy:  0.484, Validation Accuracy:  0.512, Loss:  1.755
# Epoch   1 Batch   80/269 - Train Accuracy:  0.491, Validation Accuracy:  0.500, Loss:  1.705
# Epoch   1 Batch   81/269 - Train Accuracy:  0.490, Validation Accuracy:  0.514, Loss:  1.774
# Epoch   1 Batch   82/269 - Train Accuracy:  0.500, Validation Accuracy:  0.513, Loss:  1.696
# Epoch   1 Batch   83/269 - Train Accuracy:  0.486, Validation Accuracy:  0.500, Loss:  1.708
# Epoch   1 Batch   84/269 - Train Accuracy:  0.485, Validation Accuracy:  0.509, Loss:  1.732
# Epoch   1 Batch   85/269 - Train Accuracy:  0.473, Validation Accuracy:  0.501, Loss:  1.746
# Epoch   1 Batch   86/269 - Train Accuracy:  0.480, Validation Accuracy:  0.508, Loss:  1.756
# Epoch   1 Batch   87/269 - Train Accuracy:  0.445, Validation Accuracy:  0.513, Loss:  1.860
# Epoch   1 Batch   88/269 - Train Accuracy:  0.491, Validation Accuracy:  0.506, Loss:  1.728
# Epoch   1 Batch   89/269 - Train Accuracy:  0.499, Validation Accuracy:  0.512, Loss:  1.721
# Epoch   1 Batch   90/269 - Train Accuracy:  0.445, Validation Accuracy:  0.507, Loss:  1.804
# Epoch   1 Batch   91/269 - Train Accuracy:  0.483, Validation Accuracy:  0.509, Loss:  1.700
# Epoch   1 Batch   92/269 - Train Accuracy:  0.486, Validation Accuracy:  0.511, Loss:  1.699
# Epoch   1 Batch   93/269 - Train Accuracy:  0.501, Validation Accuracy:  0.505, Loss:  1.647
# Epoch   1 Batch   94/269 - Train Accuracy:  0.489, Validation Accuracy:  0.510, Loss:  1.711
# Epoch   1 Batch   95/269 - Train Accuracy:  0.492, Validation Accuracy:  0.511, Loss:  1.683
# Epoch   1 Batch   96/269 - Train Accuracy:  0.482, Validation Accuracy:  0.505, Loss:  1.670
# Epoch   1 Batch   97/269 - Train Accuracy:  0.483, Validation Accuracy:  0.510, Loss:  1.704
# Epoch   1 Batch   98/269 - Train Accuracy:  0.502, Validation Accuracy:  0.509, Loss:  1.660
# Epoch   1 Batch   99/269 - Train Accuracy:  0.456, Validation Accuracy:  0.498, Loss:  1.787
# Epoch   1 Batch  100/269 - Train Accuracy:  0.508, Validation Accuracy:  0.512, Loss:  1.631
# Epoch   1 Batch  101/269 - Train Accuracy:  0.454, Validation Accuracy:  0.506, Loss:  1.761
# Epoch   1 Batch  102/269 - Train Accuracy:  0.480, Validation Accuracy:  0.502, Loss:  1.661
# Epoch   1 Batch  103/269 - Train Accuracy:  0.489, Validation Accuracy:  0.509, Loss:  1.665
# Epoch   1 Batch  104/269 - Train Accuracy:  0.462, Validation Accuracy:  0.495, Loss:  1.684
# Epoch   1 Batch  105/269 - Train Accuracy:  0.480, Validation Accuracy:  0.509, Loss:  1.682
# Epoch   1 Batch  106/269 - Train Accuracy:  0.472, Validation Accuracy:  0.505, Loss:  1.664
# Epoch   1 Batch  107/269 - Train Accuracy:  0.441, Validation Accuracy:  0.501, Loss:  1.734
# Epoch   1 Batch  108/269 - Train Accuracy:  0.479, Validation Accuracy:  0.506, Loss:  1.649
# Epoch   1 Batch  109/269 - Train Accuracy:  0.473, Validation Accuracy:  0.505, Loss:  1.666
# Epoch   1 Batch  110/269 - Train Accuracy:  0.479, Validation Accuracy:  0.506, Loss:  1.651
# Epoch   1 Batch  111/269 - Train Accuracy:  0.454, Validation Accuracy:  0.510, Loss:  1.766
# Epoch   1 Batch  112/269 - Train Accuracy:  0.483, Validation Accuracy:  0.503, Loss:  1.636
# Epoch   1 Batch  113/269 - Train Accuracy:  0.500, Validation Accuracy:  0.506, Loss:  1.551
# Epoch   1 Batch  114/269 - Train Accuracy:  0.481, Validation Accuracy:  0.507, Loss:  1.631
# Epoch   1 Batch  115/269 - Train Accuracy:  0.454, Validation Accuracy:  0.498, Loss:  1.696
# Epoch   1 Batch  116/269 - Train Accuracy:  0.488, Validation Accuracy:  0.505, Loss:  1.651
# Epoch   1 Batch  117/269 - Train Accuracy:  0.481, Validation Accuracy:  0.509, Loss:  1.621
# Epoch   1 Batch  118/269 - Train Accuracy:  0.489, Validation Accuracy:  0.490, Loss:  1.567
# Epoch   1 Batch  119/269 - Train Accuracy:  0.465, Validation Accuracy:  0.510, Loss:  1.705
# Epoch   1 Batch  120/269 - Train Accuracy:  0.467, Validation Accuracy:  0.515, Loss:  1.669
# Epoch   1 Batch  121/269 - Train Accuracy:  0.471, Validation Accuracy:  0.496, Loss:  1.601
# Epoch   1 Batch  122/269 - Train Accuracy:  0.495, Validation Accuracy:  0.503, Loss:  1.593
# Epoch   1 Batch  123/269 - Train Accuracy:  0.452, Validation Accuracy:  0.510, Loss:  1.669
# Epoch   1 Batch  124/269 - Train Accuracy:  0.479, Validation Accuracy:  0.504, Loss:  1.577
# Epoch   1 Batch  125/269 - Train Accuracy:  0.479, Validation Accuracy:  0.501, Loss:  1.544
# Epoch   1 Batch  126/269 - Train Accuracy:  0.486, Validation Accuracy:  0.506, Loss:  1.556
# Epoch   1 Batch  127/269 - Train Accuracy:  0.451, Validation Accuracy:  0.500, Loss:  1.666
# Epoch   1 Batch  128/269 - Train Accuracy:  0.483, Validation Accuracy:  0.502, Loss:  1.559
# Epoch   1 Batch  129/269 - Train Accuracy:  0.475, Validation Accuracy:  0.508, Loss:  1.578
# Epoch   1 Batch  130/269 - Train Accuracy:  0.455, Validation Accuracy:  0.504, Loss:  1.685
# Epoch   1 Batch  131/269 - Train Accuracy:  0.461, Validation Accuracy:  0.506, Loss:  1.620
# Epoch   1 Batch  132/269 - Train Accuracy:  0.478, Validation Accuracy:  0.506, Loss:  1.565
# Epoch   1 Batch  133/269 - Train Accuracy:  0.467, Validation Accuracy:  0.496, Loss:  1.551
# Epoch   1 Batch  134/269 - Train Accuracy:  0.429, Validation Accuracy:  0.494, Loss:  1.623
# Epoch   1 Batch  135/269 - Train Accuracy:  0.422, Validation Accuracy:  0.492, Loss:  1.659
# Epoch   1 Batch  136/269 - Train Accuracy:  0.435, Validation Accuracy:  0.492, Loss:  1.632
# Epoch   1 Batch  137/269 - Train Accuracy:  0.442, Validation Accuracy:  0.487, Loss:  1.625
# Epoch   1 Batch  138/269 - Train Accuracy:  0.433, Validation Accuracy:  0.481, Loss:  1.560
# Epoch   1 Batch  139/269 - Train Accuracy:  0.468, Validation Accuracy:  0.489, Loss:  1.504
# Epoch   1 Batch  140/269 - Train Accuracy:  0.463, Validation Accuracy:  0.491, Loss:  1.532
# Epoch   1 Batch  141/269 - Train Accuracy:  0.456, Validation Accuracy:  0.500, Loss:  1.565
# Epoch   1 Batch  142/269 - Train Accuracy:  0.490, Validation Accuracy:  0.507, Loss:  1.511
# Epoch   1 Batch  143/269 - Train Accuracy:  0.485, Validation Accuracy:  0.506, Loss:  1.525
# Epoch   1 Batch  144/269 - Train Accuracy:  0.488, Validation Accuracy:  0.507, Loss:  1.512
# Epoch   1 Batch  145/269 - Train Accuracy:  0.474, Validation Accuracy:  0.503, Loss:  1.525
# Epoch   1 Batch  146/269 - Train Accuracy:  0.486, Validation Accuracy:  0.505, Loss:  1.495
# Epoch   1 Batch  147/269 - Train Accuracy:  0.508, Validation Accuracy:  0.509, Loss:  1.454
# Epoch   1 Batch  148/269 - Train Accuracy:  0.471, Validation Accuracy:  0.508, Loss:  1.556
# Epoch   1 Batch  149/269 - Train Accuracy:  0.491, Validation Accuracy:  0.506, Loss:  1.505
# Epoch   1 Batch  150/269 - Train Accuracy:  0.484, Validation Accuracy:  0.506, Loss:  1.519
# Epoch   1 Batch  151/269 - Train Accuracy:  0.522, Validation Accuracy:  0.512, Loss:  1.430
# Epoch   1 Batch  152/269 - Train Accuracy:  0.488, Validation Accuracy:  0.515, Loss:  1.511
# Epoch   1 Batch  153/269 - Train Accuracy:  0.498, Validation Accuracy:  0.509, Loss:  1.485
# Epoch   1 Batch  154/269 - Train Accuracy:  0.452, Validation Accuracy:  0.512, Loss:  1.573
# Epoch   1 Batch  155/269 - Train Accuracy:  0.524, Validation Accuracy:  0.511, Loss:  1.414
# Epoch   1 Batch  156/269 - Train Accuracy:  0.468, Validation Accuracy:  0.505, Loss:  1.530
# Epoch   1 Batch  157/269 - Train Accuracy:  0.471, Validation Accuracy:  0.503, Loss:  1.496
# Epoch   1 Batch  158/269 - Train Accuracy:  0.472, Validation Accuracy:  0.496, Loss:  1.465
# Epoch   1 Batch  159/269 - Train Accuracy:  0.476, Validation Accuracy:  0.502, Loss:  1.486
# Epoch   1 Batch  160/269 - Train Accuracy:  0.478, Validation Accuracy:  0.501, Loss:  1.504
# Epoch   1 Batch  161/269 - Train Accuracy:  0.446, Validation Accuracy:  0.486, Loss:  1.492
# Epoch   1 Batch  162/269 - Train Accuracy:  0.473, Validation Accuracy:  0.504, Loss:  1.467
# Epoch   1 Batch  163/269 - Train Accuracy:  0.480, Validation Accuracy:  0.496, Loss:  1.480
# Epoch   1 Batch  164/269 - Train Accuracy:  0.478, Validation Accuracy:  0.494, Loss:  1.468
# Epoch   1 Batch  165/269 - Train Accuracy:  0.444, Validation Accuracy:  0.497, Loss:  1.516
# Epoch   1 Batch  166/269 - Train Accuracy:  0.513, Validation Accuracy:  0.502, Loss:  1.393
# Epoch   1 Batch  167/269 - Train Accuracy:  0.480, Validation Accuracy:  0.499, Loss:  1.461
# Epoch   1 Batch  168/269 - Train Accuracy:  0.474, Validation Accuracy:  0.491, Loss:  1.479
# Epoch   1 Batch  169/269 - Train Accuracy:  0.469, Validation Accuracy:  0.497, Loss:  1.462
# Epoch   1 Batch  170/269 - Train Accuracy:  0.485, Validation Accuracy:  0.497, Loss:  1.461
# Epoch   1 Batch  171/269 - Train Accuracy:  0.447, Validation Accuracy:  0.491, Loss:  1.494
# Epoch   1 Batch  172/269 - Train Accuracy:  0.476, Validation Accuracy:  0.505, Loss:  1.475
# Epoch   1 Batch  173/269 - Train Accuracy:  0.473, Validation Accuracy:  0.498, Loss:  1.461
# Epoch   1 Batch  174/269 - Train Accuracy:  0.478, Validation Accuracy:  0.498, Loss:  1.459
# Epoch   1 Batch  175/269 - Train Accuracy:  0.479, Validation Accuracy:  0.502, Loss:  1.475
# Epoch   1 Batch  176/269 - Train Accuracy:  0.463, Validation Accuracy:  0.505, Loss:  1.517
# Epoch   1 Batch  177/269 - Train Accuracy:  0.500, Validation Accuracy:  0.501, Loss:  1.400
# Epoch   1 Batch  178/269 - Train Accuracy:  0.467, Validation Accuracy:  0.501, Loss:  1.509
# Epoch   1 Batch  179/269 - Train Accuracy:  0.483, Validation Accuracy:  0.499, Loss:  1.424
# Epoch   1 Batch  180/269 - Train Accuracy:  0.476, Validation Accuracy:  0.497, Loss:  1.412
# Epoch   1 Batch  181/269 - Train Accuracy:  0.480, Validation Accuracy:  0.511, Loss:  1.424
# Epoch   1 Batch  182/269 - Train Accuracy:  0.486, Validation Accuracy:  0.501, Loss:  1.451
# Epoch   1 Batch  183/269 - Train Accuracy:  0.557, Validation Accuracy:  0.507, Loss:  1.239
# Epoch   1 Batch  184/269 - Train Accuracy:  0.464, Validation Accuracy:  0.511, Loss:  1.476
# Epoch   1 Batch  185/269 - Train Accuracy:  0.487, Validation Accuracy:  0.507, Loss:  1.412
# Epoch   1 Batch  186/269 - Train Accuracy:  0.455, Validation Accuracy:  0.500, Loss:  1.479
# Epoch   1 Batch  187/269 - Train Accuracy:  0.462, Validation Accuracy:  0.480, Loss:  1.385
# Epoch   1 Batch  188/269 - Train Accuracy:  0.481, Validation Accuracy:  0.496, Loss:  1.380
# Epoch   1 Batch  189/269 - Train Accuracy:  0.482, Validation Accuracy:  0.499, Loss:  1.395
# Epoch   1 Batch  190/269 - Train Accuracy:  0.465, Validation Accuracy:  0.496, Loss:  1.393
# Epoch   1 Batch  191/269 - Train Accuracy:  0.473, Validation Accuracy:  0.496, Loss:  1.426
# Epoch   1 Batch  192/269 - Train Accuracy:  0.475, Validation Accuracy:  0.504, Loss:  1.421
# Epoch   1 Batch  193/269 - Train Accuracy:  0.472, Validation Accuracy:  0.499, Loss:  1.403
# Epoch   1 Batch  194/269 - Train Accuracy:  0.488, Validation Accuracy:  0.506, Loss:  1.416
# Epoch   1 Batch  195/269 - Train Accuracy:  0.470, Validation Accuracy:  0.509, Loss:  1.422
# Epoch   1 Batch  196/269 - Train Accuracy:  0.477, Validation Accuracy:  0.505, Loss:  1.382
# Epoch   1 Batch  197/269 - Train Accuracy:  0.458, Validation Accuracy:  0.504, Loss:  1.457
# Epoch   1 Batch  198/269 - Train Accuracy:  0.459, Validation Accuracy:  0.507, Loss:  1.508
# Epoch   1 Batch  199/269 - Train Accuracy:  0.489, Validation Accuracy:  0.506, Loss:  1.437
# Epoch   1 Batch  200/269 - Train Accuracy:  0.473, Validation Accuracy:  0.509, Loss:  1.444
# Epoch   1 Batch  201/269 - Train Accuracy:  0.496, Validation Accuracy:  0.511, Loss:  1.397
# Epoch   1 Batch  202/269 - Train Accuracy:  0.497, Validation Accuracy:  0.509, Loss:  1.413
# Epoch   1 Batch  203/269 - Train Accuracy:  0.463, Validation Accuracy:  0.512, Loss:  1.456
# Epoch   1 Batch  204/269 - Train Accuracy:  0.465, Validation Accuracy:  0.513, Loss:  1.431
# Epoch   1 Batch  205/269 - Train Accuracy:  0.474, Validation Accuracy:  0.507, Loss:  1.372
# Epoch   1 Batch  206/269 - Train Accuracy:  0.438, Validation Accuracy:  0.496, Loss:  1.477
# Epoch   1 Batch  207/269 - Train Accuracy:  0.507, Validation Accuracy:  0.510, Loss:  1.332
# Epoch   1 Batch  208/269 - Train Accuracy:  0.458, Validation Accuracy:  0.512, Loss:  1.471
# Epoch   1 Batch  209/269 - Train Accuracy:  0.464, Validation Accuracy:  0.505, Loss:  1.429
# Epoch   1 Batch  210/269 - Train Accuracy:  0.487, Validation Accuracy:  0.505, Loss:  1.365
# Epoch   1 Batch  211/269 - Train Accuracy:  0.485, Validation Accuracy:  0.500, Loss:  1.360
# Epoch   1 Batch  212/269 - Train Accuracy:  0.488, Validation Accuracy:  0.504, Loss:  1.330
# Epoch   1 Batch  213/269 - Train Accuracy:  0.486, Validation Accuracy:  0.501, Loss:  1.353
# Epoch   1 Batch  214/269 - Train Accuracy:  0.482, Validation Accuracy:  0.503, Loss:  1.371
# Epoch   1 Batch  215/269 - Train Accuracy:  0.503, Validation Accuracy:  0.506, Loss:  1.289
# Epoch   1 Batch  216/269 - Train Accuracy:  0.448, Validation Accuracy:  0.498, Loss:  1.458
# Epoch   1 Batch  217/269 - Train Accuracy:  0.453, Validation Accuracy:  0.505, Loss:  1.435
# Epoch   1 Batch  218/269 - Train Accuracy:  0.469, Validation Accuracy:  0.502, Loss:  1.427
# Epoch   1 Batch  219/269 - Train Accuracy:  0.475, Validation Accuracy:  0.504, Loss:  1.405
# Epoch   1 Batch  220/269 - Train Accuracy:  0.502, Validation Accuracy:  0.507, Loss:  1.308
# Epoch   1 Batch  221/269 - Train Accuracy:  0.497, Validation Accuracy:  0.500, Loss:  1.348
# Epoch   1 Batch  222/269 - Train Accuracy:  0.486, Validation Accuracy:  0.501, Loss:  1.310
# Epoch   1 Batch  223/269 - Train Accuracy:  0.491, Validation Accuracy:  0.507, Loss:  1.316
# Epoch   1 Batch  224/269 - Train Accuracy:  0.497, Validation Accuracy:  0.508, Loss:  1.361
# Epoch   1 Batch  225/269 - Train Accuracy:  0.467, Validation Accuracy:  0.504, Loss:  1.398
# Epoch   1 Batch  226/269 - Train Accuracy:  0.473, Validation Accuracy:  0.502, Loss:  1.343
# Epoch   1 Batch  227/269 - Train Accuracy:  0.557, Validation Accuracy:  0.509, Loss:  1.186
# Epoch   1 Batch  228/269 - Train Accuracy:  0.484, Validation Accuracy:  0.510, Loss:  1.344
# Epoch   1 Batch  229/269 - Train Accuracy:  0.484, Validation Accuracy:  0.506, Loss:  1.343
# Epoch   1 Batch  230/269 - Train Accuracy:  0.476, Validation Accuracy:  0.510, Loss:  1.349
# Epoch   1 Batch  231/269 - Train Accuracy:  0.449, Validation Accuracy:  0.507, Loss:  1.409
# Epoch   1 Batch  232/269 - Train Accuracy:  0.437, Validation Accuracy:  0.500, Loss:  1.395
# Epoch   1 Batch  233/269 - Train Accuracy:  0.483, Validation Accuracy:  0.510, Loss:  1.351
# Epoch   1 Batch  234/269 - Train Accuracy:  0.479, Validation Accuracy:  0.507, Loss:  1.345
# Epoch   1 Batch  235/269 - Train Accuracy:  0.476, Validation Accuracy:  0.503, Loss:  1.339
# Epoch   1 Batch  236/269 - Train Accuracy:  0.483, Validation Accuracy:  0.508, Loss:  1.331
# Epoch   1 Batch  237/269 - Train Accuracy:  0.472, Validation Accuracy:  0.497, Loss:  1.338
# Epoch   1 Batch  238/269 - Train Accuracy:  0.488, Validation Accuracy:  0.510, Loss:  1.334
# Epoch   1 Batch  239/269 - Train Accuracy:  0.494, Validation Accuracy:  0.514, Loss:  1.317
# Epoch   1 Batch  240/269 - Train Accuracy:  0.509, Validation Accuracy:  0.503, Loss:  1.237
# Epoch   1 Batch  241/269 - Train Accuracy:  0.494, Validation Accuracy:  0.507, Loss:  1.325
# Epoch   1 Batch  242/269 - Train Accuracy:  0.480, Validation Accuracy:  0.511, Loss:  1.320
# Epoch   1 Batch  243/269 - Train Accuracy:  0.494, Validation Accuracy:  0.505, Loss:  1.294
# Epoch   1 Batch  244/269 - Train Accuracy:  0.468, Validation Accuracy:  0.501, Loss:  1.321
# Epoch   1 Batch  245/269 - Train Accuracy:  0.439, Validation Accuracy:  0.490, Loss:  1.410
# Epoch   1 Batch  246/269 - Train Accuracy:  0.479, Validation Accuracy:  0.501, Loss:  1.329
# Epoch   1 Batch  247/269 - Train Accuracy:  0.477, Validation Accuracy:  0.512, Loss:  1.361
# ...
# Epoch  19 Batch   97/269 - Train Accuracy:  0.753, Validation Accuracy:  0.768, Loss:  0.267
# Epoch  19 Batch   98/269 - Train Accuracy:  0.764, Validation Accuracy:  0.766, Loss:  0.265
# Epoch  19 Batch   99/269 - Train Accuracy:  0.763, Validation Accuracy:  0.767, Loss:  0.264
# Epoch  19 Batch  100/269 - Train Accuracy:  0.795, Validation Accuracy:  0.776, Loss:  0.263
# Epoch  19 Batch  101/269 - Train Accuracy:  0.730, Validation Accuracy:  0.772, Loss:  0.285
# Epoch  19 Batch  102/269 - Train Accuracy:  0.765, Validation Accuracy:  0.770, Loss:  0.255
# Epoch  19 Batch  103/269 - Train Accuracy:  0.761, Validation Accuracy:  0.764, Loss:  0.261
# Epoch  19 Batch  104/269 - Train Accuracy:  0.754, Validation Accuracy:  0.769, Loss:  0.262
# Epoch  19 Batch  105/269 - Train Accuracy:  0.761, Validation Accuracy:  0.766, Loss:  0.276
# Epoch  19 Batch  106/269 - Train Accuracy:  0.745, Validation Accuracy:  0.761, Loss:  0.261
# Epoch  19 Batch  107/269 - Train Accuracy:  0.741, Validation Accuracy:  0.768, Loss:  0.275
# Epoch  19 Batch  108/269 - Train Accuracy:  0.763, Validation Accuracy:  0.767, Loss:  0.263
# Epoch  19 Batch  109/269 - Train Accuracy:  0.721, Validation Accuracy:  0.770, Loss:  0.269
# Epoch  19 Batch  110/269 - Train Accuracy:  0.749, Validation Accuracy:  0.767, Loss:  0.256
# Epoch  19 Batch  111/269 - Train Accuracy:  0.742, Validation Accuracy:  0.766, Loss:  0.291
# Epoch  19 Batch  112/269 - Train Accuracy:  0.768, Validation Accuracy:  0.768, Loss:  0.271
# Epoch  19 Batch  113/269 - Train Accuracy:  0.747, Validation Accuracy:  0.767, Loss:  0.260
# Epoch  19 Batch  114/269 - Train Accuracy:  0.749, Validation Accuracy:  0.769, Loss:  0.260
# Epoch  19 Batch  115/269 - Train Accuracy:  0.740, Validation Accuracy:  0.766, Loss:  0.280
# Epoch  19 Batch  116/269 - Train Accuracy:  0.769, Validation Accuracy:  0.768, Loss:  0.264
# Epoch  19 Batch  117/269 - Train Accuracy:  0.755, Validation Accuracy:  0.767, Loss:  0.265
# Epoch  19 Batch  118/269 - Train Accuracy:  0.789, Validation Accuracy:  0.763, Loss:  0.251
# Epoch  19 Batch  119/269 - Train Accuracy:  0.767, Validation Accuracy:  0.773, Loss:  0.266
# Epoch  19 Batch  120/269 - Train Accuracy:  0.756, Validation Accuracy:  0.773, Loss:  0.280
# Epoch  19 Batch  121/269 - Train Accuracy:  0.766, Validation Accuracy:  0.766, Loss:  0.257
# Epoch  19 Batch  122/269 - Train Accuracy:  0.767, Validation Accuracy:  0.774, Loss:  0.258
# Epoch  19 Batch  123/269 - Train Accuracy:  0.748, Validation Accuracy:  0.773, Loss:  0.266
# Epoch  19 Batch  124/269 - Train Accuracy:  0.761, Validation Accuracy:  0.764, Loss:  0.252
# Epoch  19 Batch  125/269 - Train Accuracy:  0.748, Validation Accuracy:  0.770, Loss:  0.262
# Epoch  19 Batch  126/269 - Train Accuracy:  0.750, Validation Accuracy:  0.767, Loss:  0.270
# Epoch  19 Batch  127/269 - Train Accuracy:  0.759, Validation Accuracy:  0.771, Loss:  0.275
# Epoch  19 Batch  128/269 - Train Accuracy:  0.774, Validation Accuracy:  0.766, Loss:  0.268
# Epoch  19 Batch  129/269 - Train Accuracy:  0.762, Validation Accuracy:  0.762, Loss:  0.264
# Epoch  19 Batch  130/269 - Train Accuracy:  0.746, Validation Accuracy:  0.768, Loss:  0.273
# Epoch  19 Batch  131/269 - Train Accuracy:  0.748, Validation Accuracy:  0.764, Loss:  0.270
# Epoch  19 Batch  132/269 - Train Accuracy:  0.744, Validation Accuracy:  0.765, Loss:  0.284
# Epoch  19 Batch  133/269 - Train Accuracy:  0.756, Validation Accuracy:  0.759, Loss:  0.255
# Epoch  19 Batch  134/269 - Train Accuracy:  0.750, Validation Accuracy:  0.768, Loss:  0.271
# Epoch  19 Batch  135/269 - Train Accuracy:  0.739, Validation Accuracy:  0.772, Loss:  0.288
# Epoch  19 Batch  136/269 - Train Accuracy:  0.734, Validation Accuracy:  0.757, Loss:  0.274
# Epoch  19 Batch  137/269 - Train Accuracy:  0.761, Validation Accuracy:  0.765, Loss:  0.291
# Epoch  19 Batch  138/269 - Train Accuracy:  0.752, Validation Accuracy:  0.761, Loss:  0.267
# Epoch  19 Batch  139/269 - Train Accuracy:  0.777, Validation Accuracy:  0.768, Loss:  0.258
# Epoch  19 Batch  140/269 - Train Accuracy:  0.753, Validation Accuracy:  0.766, Loss:  0.272
# Epoch  19 Batch  141/269 - Train Accuracy:  0.756, Validation Accuracy:  0.769, Loss:  0.273
# Epoch  19 Batch  142/269 - Train Accuracy:  0.758, Validation Accuracy:  0.768, Loss:  0.254
# Epoch  19 Batch  143/269 - Train Accuracy:  0.765, Validation Accuracy:  0.770, Loss:  0.258
# Epoch  19 Batch  144/269 - Train Accuracy:  0.757, Validation Accuracy:  0.766, Loss:  0.241
# Epoch  19 Batch  145/269 - Train Accuracy:  0.764, Validation Accuracy:  0.768, Loss:  0.261
# Epoch  19 Batch  146/269 - Train Accuracy:  0.754, Validation Accuracy:  0.767, Loss:  0.255
# Epoch  19 Batch  147/269 - Train Accuracy:  0.775, Validation Accuracy:  0.768, Loss:  0.258
# Epoch  19 Batch  148/269 - Train Accuracy:  0.757, Validation Accuracy:  0.770, Loss:  0.263
# Epoch  19 Batch  149/269 - Train Accuracy:  0.755, Validation Accuracy:  0.769, Loss:  0.264
# Epoch  19 Batch  150/269 - Train Accuracy:  0.766, Validation Accuracy:  0.767, Loss:  0.260
# Epoch  19 Batch  151/269 - Train Accuracy:  0.788, Validation Accuracy:  0.769, Loss:  0.253
# Epoch  19 Batch  152/269 - Train Accuracy:  0.755, Validation Accuracy:  0.767, Loss:  0.260
# Epoch  19 Batch  153/269 - Train Accuracy:  0.765, Validation Accuracy:  0.773, Loss:  0.256
# Epoch  19 Batch  154/269 - Train Accuracy:  0.747, Validation Accuracy:  0.767, Loss:  0.262
# Epoch  19 Batch  155/269 - Train Accuracy:  0.779, Validation Accuracy:  0.771, Loss:  0.254
# Epoch  19 Batch  156/269 - Train Accuracy:  0.753, Validation Accuracy:  0.759, Loss:  0.266
# Epoch  19 Batch  157/269 - Train Accuracy:  0.759, Validation Accuracy:  0.763, Loss:  0.257
# Epoch  19 Batch  158/269 - Train Accuracy:  0.759, Validation Accuracy:  0.763, Loss:  0.259
# Epoch  19 Batch  159/269 - Train Accuracy:  0.767, Validation Accuracy:  0.766, Loss:  0.261
# Epoch  19 Batch  160/269 - Train Accuracy:  0.769, Validation Accuracy:  0.767, Loss:  0.251
# Epoch  19 Batch  161/269 - Train Accuracy:  0.758, Validation Accuracy:  0.773, Loss:  0.255
# Epoch  19 Batch  162/269 - Train Accuracy:  0.770, Validation Accuracy:  0.775, Loss:  0.257
# Epoch  19 Batch  163/269 - Train Accuracy:  0.774, Validation Accuracy:  0.774, Loss:  0.263
# Epoch  19 Batch  164/269 - Train Accuracy:  0.765, Validation Accuracy:  0.775, Loss:  0.255
# Epoch  19 Batch  165/269 - Train Accuracy:  0.741, Validation Accuracy:  0.772, Loss:  0.265
# Epoch  19 Batch  166/269 - Train Accuracy:  0.778, Validation Accuracy:  0.773, Loss:  0.239
# Epoch  19 Batch  167/269 - Train Accuracy:  0.764, Validation Accuracy:  0.773, Loss:  0.255
# Epoch  19 Batch  168/269 - Train Accuracy:  0.768, Validation Accuracy:  0.775, Loss:  0.255
# Epoch  19 Batch  169/269 - Train Accuracy:  0.755, Validation Accuracy:  0.773, Loss:  0.268
# Epoch  19 Batch  170/269 - Train Accuracy:  0.762, Validation Accuracy:  0.768, Loss:  0.249
# Epoch  19 Batch  171/269 - Train Accuracy:  0.755, Validation Accuracy:  0.769, Loss:  0.263
# Epoch  19 Batch  172/269 - Train Accuracy:  0.760, Validation Accuracy:  0.774, Loss:  0.269
# Epoch  19 Batch  173/269 - Train Accuracy:  0.763, Validation Accuracy:  0.775, Loss:  0.246
# Epoch  19 Batch  174/269 - Train Accuracy:  0.762, Validation Accuracy:  0.772, Loss:  0.259
# Epoch  19 Batch  175/269 - Train Accuracy:  0.770, Validation Accuracy:  0.772, Loss:  0.275
# Epoch  19 Batch  176/269 - Train Accuracy:  0.744, Validation Accuracy:  0.771, Loss:  0.269
# Epoch  19 Batch  177/269 - Train Accuracy:  0.773, Validation Accuracy:  0.776, Loss:  0.250
# Epoch  19 Batch  178/269 - Train Accuracy:  0.762, Validation Accuracy:  0.771, Loss:  0.253
# Epoch  19 Batch  179/269 - Train Accuracy:  0.766, Validation Accuracy:  0.770, Loss:  0.257
# Epoch  19 Batch  180/269 - Train Accuracy:  0.768, Validation Accuracy:  0.775, Loss:  0.255
# Epoch  19 Batch  181/269 - Train Accuracy:  0.754, Validation Accuracy:  0.772, Loss:  0.261
# Epoch  19 Batch  182/269 - Train Accuracy:  0.778, Validation Accuracy:  0.771, Loss:  0.259
# Epoch  19 Batch  183/269 - Train Accuracy:  0.799, Validation Accuracy:  0.767, Loss:  0.233
# Epoch  19 Batch  184/269 - Train Accuracy:  0.762, Validation Accuracy:  0.769, Loss:  0.262
# Epoch  19 Batch  185/269 - Train Accuracy:  0.773, Validation Accuracy:  0.769, Loss:  0.248
# Epoch  19 Batch  186/269 - Train Accuracy:  0.749, Validation Accuracy:  0.773, Loss:  0.270
# Epoch  19 Batch  187/269 - Train Accuracy:  0.767, Validation Accuracy:  0.771, Loss:  0.251
# Epoch  19 Batch  188/269 - Train Accuracy:  0.785, Validation Accuracy:  0.774, Loss:  0.249
# Epoch  19 Batch  189/269 - Train Accuracy:  0.766, Validation Accuracy:  0.776, Loss:  0.243
# Epoch  19 Batch  190/269 - Train Accuracy:  0.760, Validation Accuracy:  0.773, Loss:  0.249
# Epoch  19 Batch  191/269 - Train Accuracy:  0.774, Validation Accuracy:  0.775, Loss:  0.251
# Epoch  19 Batch  192/269 - Train Accuracy:  0.769, Validation Accuracy:  0.772, Loss:  0.246
# Epoch  19 Batch  193/269 - Train Accuracy:  0.769, Validation Accuracy:  0.771, Loss:  0.244
# Epoch  19 Batch  194/269 - Train Accuracy:  0.775, Validation Accuracy:  0.775, Loss:  0.256
# Epoch  19 Batch  195/269 - Train Accuracy:  0.773, Validation Accuracy:  0.773, Loss:  0.256
# Epoch  19 Batch  196/269 - Train Accuracy:  0.754, Validation Accuracy:  0.772, Loss:  0.251
# Epoch  19 Batch  197/269 - Train Accuracy:  0.733, Validation Accuracy:  0.774, Loss:  0.267
# Epoch  19 Batch  198/269 - Train Accuracy:  0.753, Validation Accuracy:  0.773, Loss:  0.267
# Epoch  19 Batch  199/269 - Train Accuracy:  0.752, Validation Accuracy:  0.771, Loss:  0.257
# Epoch  19 Batch  200/269 - Train Accuracy:  0.765, Validation Accuracy:  0.773, Loss:  0.263
# Epoch  19 Batch  201/269 - Train Accuracy:  0.761, Validation Accuracy:  0.769, Loss:  0.251
# Epoch  19 Batch  202/269 - Train Accuracy:  0.751, Validation Accuracy:  0.772, Loss:  0.264
# Epoch  19 Batch  203/269 - Train Accuracy:  0.761, Validation Accuracy:  0.776, Loss:  0.269
# Epoch  19 Batch  204/269 - Train Accuracy:  0.751, Validation Accuracy:  0.772, Loss:  0.261
# Epoch  19 Batch  205/269 - Train Accuracy:  0.751, Validation Accuracy:  0.772, Loss:  0.253
# Epoch  19 Batch  206/269 - Train Accuracy:  0.755, Validation Accuracy:  0.773, Loss:  0.273
# Epoch  19 Batch  207/269 - Train Accuracy:  0.785, Validation Accuracy:  0.778, Loss:  0.247
# Epoch  19 Batch  208/269 - Train Accuracy:  0.767, Validation Accuracy:  0.772, Loss:  0.259
# Epoch  19 Batch  209/269 - Train Accuracy:  0.759, Validation Accuracy:  0.772, Loss:  0.258
# Epoch  19 Batch  210/269 - Train Accuracy:  0.775, Validation Accuracy:  0.775, Loss:  0.254
# Epoch  19 Batch  211/269 - Train Accuracy:  0.769, Validation Accuracy:  0.775, Loss:  0.255
# Epoch  19 Batch  212/269 - Train Accuracy:  0.780, Validation Accuracy:  0.774, Loss:  0.260
# Epoch  19 Batch  213/269 - Train Accuracy:  0.758, Validation Accuracy:  0.775, Loss:  0.259
# Epoch  19 Batch  214/269 - Train Accuracy:  0.769, Validation Accuracy:  0.774, Loss:  0.260
# Epoch  19 Batch  215/269 - Train Accuracy:  0.790, Validation Accuracy:  0.774, Loss:  0.236
# Epoch  19 Batch  216/269 - Train Accuracy:  0.741, Validation Accuracy:  0.769, Loss:  0.283
# Epoch  19 Batch  217/269 - Train Accuracy:  0.742, Validation Accuracy:  0.771, Loss:  0.260
# Epoch  19 Batch  218/269 - Train Accuracy:  0.769, Validation Accuracy:  0.774, Loss:  0.261
# Epoch  19 Batch  219/269 - Train Accuracy:  0.767, Validation Accuracy:  0.773, Loss:  0.263
# Epoch  19 Batch  220/269 - Train Accuracy:  0.761, Validation Accuracy:  0.776, Loss:  0.242
# Epoch  19 Batch  221/269 - Train Accuracy:  0.778, Validation Accuracy:  0.771, Loss:  0.249
# Epoch  19 Batch  222/269 - Train Accuracy:  0.779, Validation Accuracy:  0.777, Loss:  0.248
# Epoch  19 Batch  223/269 - Train Accuracy:  0.762, Validation Accuracy:  0.776, Loss:  0.252
# Epoch  19 Batch  224/269 - Train Accuracy:  0.771, Validation Accuracy:  0.775, Loss:  0.265
# Epoch  19 Batch  225/269 - Train Accuracy:  0.772, Validation Accuracy:  0.772, Loss:  0.243
# Epoch  19 Batch  226/269 - Train Accuracy:  0.766, Validation Accuracy:  0.773, Loss:  0.254
# Epoch  19 Batch  227/269 - Train Accuracy:  0.801, Validation Accuracy:  0.774, Loss:  0.237
# Epoch  19 Batch  228/269 - Train Accuracy:  0.761, Validation Accuracy:  0.771, Loss:  0.247
# Epoch  19 Batch  229/269 - Train Accuracy:  0.762, Validation Accuracy:  0.765, Loss:  0.255
# Epoch  19 Batch  230/269 - Train Accuracy:  0.750, Validation Accuracy:  0.768, Loss:  0.252
# Epoch  19 Batch  231/269 - Train Accuracy:  0.743, Validation Accuracy:  0.770, Loss:  0.266
# Epoch  19 Batch  232/269 - Train Accuracy:  0.742, Validation Accuracy:  0.772, Loss:  0.274
# Epoch  19 Batch  233/269 - Train Accuracy:  0.776, Validation Accuracy:  0.764, Loss:  0.253
# Epoch  19 Batch  234/269 - Train Accuracy:  0.763, Validation Accuracy:  0.770, Loss:  0.248
# Epoch  19 Batch  235/269 - Train Accuracy:  0.785, Validation Accuracy:  0.768, Loss:  0.233
# Epoch  19 Batch  236/269 - Train Accuracy:  0.769, Validation Accuracy:  0.769, Loss:  0.244
# Epoch  19 Batch  237/269 - Train Accuracy:  0.753, Validation Accuracy:  0.767, Loss:  0.245
# Epoch  19 Batch  238/269 - Train Accuracy:  0.774, Validation Accuracy:  0.769, Loss:  0.246
# Epoch  19 Batch  239/269 - Train Accuracy:  0.775, Validation Accuracy:  0.768, Loss:  0.248
# Epoch  19 Batch  240/269 - Train Accuracy:  0.774, Validation Accuracy:  0.771, Loss:  0.221
# Epoch  19 Batch  241/269 - Train Accuracy:  0.764, Validation Accuracy:  0.772, Loss:  0.252
# Epoch  19 Batch  242/269 - Train Accuracy:  0.762, Validation Accuracy:  0.771, Loss:  0.244
# Epoch  19 Batch  243/269 - Train Accuracy:  0.780, Validation Accuracy:  0.772, Loss:  0.242
# Epoch  19 Batch  244/269 - Train Accuracy:  0.764, Validation Accuracy:  0.770, Loss:  0.253
# Epoch  19 Batch  245/269 - Train Accuracy:  0.761, Validation Accuracy:  0.771, Loss:  0.263
# Epoch  19 Batch  246/269 - Train Accuracy:  0.743, Validation Accuracy:  0.776, Loss:  0.249
# Epoch  19 Batch  247/269 - Train Accuracy:  0.763, Validation Accuracy:  0.774, Loss:  0.253
# Epoch  19 Batch  248/269 - Train Accuracy:  0.764, Validation Accuracy:  0.778, Loss:  0.244
# Epoch  19 Batch  249/269 - Train Accuracy:  0.788, Validation Accuracy:  0.773, Loss:  0.226
# Epoch  19 Batch  250/269 - Train Accuracy:  0.766, Validation Accuracy:  0.774, Loss:  0.246
# Epoch  19 Batch  251/269 - Train Accuracy:  0.792, Validation Accuracy:  0.777, Loss:  0.240
# Epoch  19 Batch  252/269 - Train Accuracy:  0.765, Validation Accuracy:  0.774, Loss:  0.254
# Epoch  19 Batch  253/269 - Train Accuracy:  0.756, Validation Accuracy:  0.771, Loss:  0.256
# Epoch  19 Batch  254/269 - Train Accuracy:  0.765, Validation Accuracy:  0.775, Loss:  0.252
# Epoch  19 Batch  255/269 - Train Accuracy:  0.792, Validation Accuracy:  0.772, Loss:  0.228
# Epoch  19 Batch  256/269 - Train Accuracy:  0.731, Validation Accuracy:  0.767, Loss:  0.261
# Epoch  19 Batch  257/269 - Train Accuracy:  0.742, Validation Accuracy:  0.773, Loss:  0.265
# Epoch  19 Batch  258/269 - Train Accuracy:  0.761, Validation Accuracy:  0.778, Loss:  0.249
# Epoch  19 Batch  259/269 - Train Accuracy:  0.783, Validation Accuracy:  0.773, Loss:  0.247
# Epoch  19 Batch  260/269 - Train Accuracy:  0.748, Validation Accuracy:  0.769, Loss:  0.264
# Epoch  19 Batch  261/269 - Train Accuracy:  0.740, Validation Accuracy:  0.767, Loss:  0.264
# Epoch  19 Batch  262/269 - Train Accuracy:  0.768, Validation Accuracy:  0.773, Loss:  0.236
# Epoch  19 Batch  263/269 - Train Accuracy:  0.779, Validation Accuracy:  0.769, Loss:  0.252
# Epoch  19 Batch  264/269 - Train Accuracy:  0.752, Validation Accuracy:  0.772, Loss:  0.253
# Epoch  19 Batch  265/269 - Train Accuracy:  0.759, Validation Accuracy:  0.771, Loss:  0.253
# Epoch  19 Batch  266/269 - Train Accuracy:  0.765, Validation Accuracy:  0.774, Loss:  0.240
# Epoch  19 Batch  267/269 - Train Accuracy:  0.771, Validation Accuracy:  0.779, Loss:  0.260
# Model Trained and Saved

# %% [markdown]
# ### Save Parameters
# Save the `batch_size` and `save_path` parameters for inference.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Save parameters for checkpoint
helper.save_params(save_path)

# %% [markdown]
# # Checkpoint

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import tensorflow as tf
import numpy as np
import helper
import problem_unittests as tests

_, (source_vocab_to_int, target_vocab_to_int), (source_int_to_vocab, target_int_to_vocab) = helper.load_preprocess()
load_path = helper.load_params()

# %% [markdown]
# ## Sentence to Sequence
# To feed a sentence into the model for translation, you first need to preprocess it.  Implement the function `sentence_to_seq()` to preprocess new sentences.
#
# - Convert the sentence to lowercase
# - Convert words into ids using `vocab_to_int`
#  - Convert words not in the vocabulary, to the `<UNK>` word id.

# %%
def sentence_to_seq(sentence, vocab_to_int):
    
    sen2seq = [vocab_to_int.get(word, vocab_to_int["<UNK>"]) for word in sentence.split()]
    return sen2seq


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_sentence_to_seq(sentence_to_seq)
# Out:
# Tests Passed

# %% [markdown]
# ## Translate
# This will translate `translate_sentence` from English to French.

# %%
translate_sentence = 'he saw a old yellow truck .'


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
translate_sentence = sentence_to_seq(translate_sentence, source_vocab_to_int)

loaded_graph = tf.Graph()
with tf.Session(graph=loaded_graph) as sess:
    # Load saved model
    loader = tf.train.import_meta_graph(load_path + '.meta')
    loader.restore(sess, load_path)

    input_data = loaded_graph.get_tensor_by_name('input:0')
    logits = loaded_graph.get_tensor_by_name('logits:0')
    keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')

    translate_logits = sess.run(logits, {input_data: [translate_sentence], keep_prob: 1.0})[0]

print('Input')
print('  Word Ids:      {}'.format([i for i in translate_sentence]))
print('  English Words: {}'.format([source_int_to_vocab[i] for i in translate_sentence]))

print('\nPrediction')
print('  Word Ids:      {}'.format([i for i in np.argmax(translate_logits, 1)]))
print('  French Words: {}'.format([target_int_to_vocab[i] for i in np.argmax(translate_logits, 1)]))
# Out:
# Input
#   Word Ids:      [10, 161, 42, 37, 141, 61, 222]
#   English Words: ['he', 'saw', 'a', 'old', 'yellow', 'truck', '.']
#
# Prediction
#   Word Ids:      [298, 93, 272, 168, 1]
#   French Words: ['il', 'les', 'citrons', '.', '<EOS>']

# %% [markdown]
# ## Imperfect Translation
# You might notice that some sentences translate better than others.  Since the dataset you're using only has a vocabulary of 227 English words of the thousands that you use, you're only going to see good results using these words.  For this project, you don't need a perfect translation. However, if you want to create a better translation model, you'll need better data.
#
# You can train on the [WMT10 French-English corpus](http://www.statmt.org/wmt10/training-giga-fren.tar).  This dataset has more vocabulary and richer in topics discussed.  However, this will take you days to train, so make sure you've a GPU and the neural network is performing well on dataset we provided.  Just make sure you play with the WMT10 corpus after you've submitted this project.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_language_translation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "helper.py" and "problem_unittests.py" files in your submission.
